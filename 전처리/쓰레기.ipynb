# %%
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/쓰레기.xlsx')
df
# Out:
#          2. 생활계폐기물 발생 및 처리현황 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      나-1). 시·군·구 생활(가정)폐기물        NaN            NaN        NaN        NaN
# 1                        NaN        NaN            NaN        NaN        NaN
# 2                         시도        시군구         폐기물 종류        NaN        NaN
# 3                        NaN        NaN            NaN        NaN        NaN
# 4                         전국         합계             합계      EMPTY      EMPTY
# ...                      ...        ...            ...        ...        ...
# 10373                    NaN        NaN            NaN    폐전기전자제품      EMPTY
# 10374                    NaN        NaN            NaN       폐가구류      EMPTY
# 10375                    NaN        NaN            NaN         기타      EMPTY
# 10376                    NaN        NaN            NaN    재활용 잔재물      EMPTY
# 10377                    NaN        NaN  음식물류 폐기물 분리배출      EMPTY      EMPTY
#
# ...

# %%
df.iloc[2:].reset_index(drop=True)
# Out:
#       2. 생활계폐기물 발생 및 처리현황 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                      시도        시군구         폐기물 종류        NaN        NaN
# 1                     NaN        NaN            NaN        NaN        NaN
# 2                      전국         합계             합계      EMPTY      EMPTY
# 3                     NaN        NaN   종량제방식 등 혼합배출         소계      EMPTY
# 4                     NaN        NaN            NaN        가연성         소계
# ...                   ...        ...            ...        ...        ...
# 10371                 NaN        NaN            NaN    폐전기전자제품      EMPTY
# 10372                 NaN        NaN            NaN       폐가구류      EMPTY
# 10373                 NaN        NaN            NaN         기타      EMPTY
# 10374                 NaN        NaN            NaN    재활용 잔재물      EMPTY
# 10375                 NaN        NaN  음식물류 폐기물 분리배출      EMPTY      EMPTY
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# ...

# %%
df1=df[~df['Unnamed: 1'].isna()].reset_index(drop=True)
df1
# Out:
#     2. 생활계폐기물 발생 및 처리현황 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    시도        시군구     폐기물 종류        NaN        NaN
# 1                    전국         합계         합계      EMPTY      EMPTY
# 2                    서울         소계         합계        NaN      EMPTY
# 3                    서울        종로구         합계        NaN      EMPTY
# 4                    서울         중구         합계        NaN      EMPTY
# ..                  ...        ...        ...        ...        ...
# 243                  경남        거창군         합계        NaN      EMPTY
# 244                  경남        합천군         합계        NaN      EMPTY
# 245                  제주         소계         합계        NaN      EMPTY
# 246                  제주        제주시         합계        NaN      EMPTY
# 247                  제주       서귀포시         합계        NaN      EMPTY
#
#      Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 12  \
# ...

# %%
df2=df1.iloc[2:][['2. 생활계폐기물 발생 및 처리현황','Unnamed: 1','Unnamed: 5']].reset_index(drop=True)
df2.rename(columns={'2. 생활계폐기물 발생 및 처리현황':'시도','Unnamed: 1':'시군구','Unnamed: 5':'배출량'},inplace=True)
df2
# Out:
#      시도   시군구        배출량
# 0    서울    소계  2905572.9
# 1    서울   종로구    95355.2
# 2    서울    중구    95998.1
# 3    서울   용산구      87049
# 4    서울   성동구    89652.9
# ..   ..   ...        ...
# 241  경남   거창군    27451.9
# 242  경남   합천군    14930.9
# 243  제주    소계   427368.3
# 244  제주   제주시   323450.3
# 245  제주  서귀포시     103918
#
# [246 rows x 3 columns]

# %%
df2.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/쓰레기_최종.csv',index=False)
