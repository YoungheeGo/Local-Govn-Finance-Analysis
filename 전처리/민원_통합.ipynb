# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
df1=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/22년 1분기 처리기간준수율.csv',encoding='cp949')
df1.head()
# Out:
#      기관유형                 기관명       계  기간내 처리  기간초과 처리  처리기간준수율
# 0  중앙행정기관  5.18민주화운동진상규명조사위원회       5       5        0   100.00
# 1  중앙행정기관           개인정보보호위원회    1064    1027       37    96.52
# 2  중앙행정기관                 경찰청  284911  284331      580    99.80
# 3  중앙행정기관               고용노동부   33826   32864      962    97.16
# 4  중앙행정기관          고위공직자범죄수사처     950     848      102    89.26

# %%
df2=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/22년 2분기 처리기간준수율.csv',encoding='cp949')
df2.head()
# Out:
#        유형                 기관명      소계  기간내 처리  기간초과 처리    준수율
# 0  중앙행정기관  5.18민주화운동진상규명조사위원회       8       7        1  87.50
# 1  중앙행정기관           개인정보보호위원회    1473    1390       83  94.37
# 2  중앙행정기관                 경찰청  382705  381778      927  99.76
# 3  중앙행정기관               고용노동부   32528   31031     1497  95.40
# 4  중앙행정기관          고위공직자범죄수사처    1385    1253      132  90.47

# %%
df3=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/22년 3분기 처리기간준수율.csv',encoding='cp949')
df3.head()
# Out:
#      기관유형                 기관명       계  기간내 처리  기간초과 처리  처리기간준수율
# 0  중앙행정기관  5.18민주화운동진상규명조사위원회       4       3        1    75.00
# 1  중앙행정기관           개인정보보호위원회    1196    1196        0   100.00
# 2  중앙행정기관                 경찰청  380642  379648      994    99.74
# 3  중앙행정기관               고용노동부   32393   29872     2521    92.22
# 4  중앙행정기관          고위공직자범죄수사처    1452    1371       81    94.42

# %%
df4=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/22년 4분기 처리기간 준수율.csv',encoding='cp949')
df4.head()
# Out:
#        유형         기관명      소계  기간내 처리  기간초과 처리     준수율
# 0  중앙행정기관   개인정보보호위원회    1235    1235        0  100.00
# 1  중앙행정기관         경찰청  340135  339174      961   99.72
# 2  중앙행정기관       고용노동부   30109   28456     1653   94.51
# 3  중앙행정기관  고위공직자범죄수사처    1735    1690       45   97.41
# 4  중앙행정기관     공정거래위원회    4508    4445       63   98.60

# %%
df1['기관유형'].unique()
# Out:
# array(['중앙행정기관', '광역-지방자치단체', '시도-지방자치단체', '시도교육청', '공공기관', '고등교육기관',
#        '헌법기관'], dtype=object)

# %%
df1_=df1[df1['기관유형']=='시도-지방자치단체'].reset_index(drop=True)
df1_
# Out:
#           기관유형       기관명      계  기간내 처리  기간초과 처리  처리기간준수율
# 0    시도-지방자치단체   강원도 강릉시   4046    3953       93    97.70
# 1    시도-지방자치단체   강원도 고성군    387     375       12    96.90
# 2    시도-지방자치단체   강원도 동해시   1877    1831       46    97.55
# 3    시도-지방자치단체   강원도 삼척시   1462    1394       68    95.35
# 4    시도-지방자치단체   강원도 속초시   2229    2133       96    95.69
# ..         ...       ...    ...     ...      ...      ...
# 223  시도-지방자치단체  충청북도 제천시   2155    2154        1    99.95
# 224  시도-지방자치단체  충청북도 증평군    971     963        8    99.18
# 225  시도-지방자치단체  충청북도 진천군   1642    1641        1    99.94
# 226  시도-지방자치단체  충청북도 청주시  36664   36534      130    99.65
# 227  시도-지방자치단체  충청북도 충주시   3745    3725       20    99.47
#
# [228 rows x 6 columns]

# %%
df1_['기관명'].unique()
# Out:
# array(['강원도 강릉시', '강원도 고성군', '강원도 동해시', '강원도 삼척시', '강원도 속초시', '강원도 양구군',
#        '강원도 양양군', '강원도 영월군', '강원도 원주시', '강원도 인제군', '강원도 정선군', '강원도 철원군',
#        '강원도 춘천시', '강원도 태백시', '강원도 평창군', '강원도 홍천군', '강원도 화천군', '강원도 횡성군',
#        '경기도 가평군', '경기도 고양시', '경기도 과천시', '경기도 광명시', '경기도 광주시', '경기도 구리시',
#        '경기도 군포시', '경기도 김포시', '경기도 남양주시', '경기도 동두천시', '경기도 부천시', '경기도 성남시',
#        '경기도 수원시', '경기도 시흥시', '경기도 안산시', '경기도 안성시', '경기도 안양시', '경기도 양주시',
#        '경기도 양평군', '경기도 여주시', '경기도 연천군', '경기도 오산시', '경기도 용인시', '경기도 의왕시',
#        '경기도 의정부시', '경기도 이천시', '경기도 파주시', '경기도 평택시', '경기도 포천시', '경기도 하남시',
#        '경기도 화성시', '경상남도 거제시', '경상남도 거창군', '경상남도 고성군', '경상남도 김해시',
#        '경상남도 남해군', '경상남도 밀양시', '경상남도 사천시', '경상남도 산청군', '경상남도 양산시',
#        '경상남도 의령군', '경상남도 진주시', '경상남도 창녕군', '경상남도 창원시', '경상남도 통영시',
#        '경상남도 하동군', '경상남도 함안군', '경상남도 함양군', '경상남도 합천군', '경상북도 경산시',
#        '경상북도 경주시', '경상북도 고령군', '경상북도 구미시', '경상북도 군위군', '경상북도 김천시',
# ...

# %%
df1_.rename(columns={'처리기간준수율':'준수율'},inplace=True)
df1_
# Out:
#           기관유형       기관명      계  기간내 처리  기간초과 처리    준수율
# 0    시도-지방자치단체   강원도 강릉시   4046    3953       93  97.70
# 1    시도-지방자치단체   강원도 고성군    387     375       12  96.90
# 2    시도-지방자치단체   강원도 동해시   1877    1831       46  97.55
# 3    시도-지방자치단체   강원도 삼척시   1462    1394       68  95.35
# 4    시도-지방자치단체   강원도 속초시   2229    2133       96  95.69
# ..         ...       ...    ...     ...      ...    ...
# 223  시도-지방자치단체  충청북도 제천시   2155    2154        1  99.95
# 224  시도-지방자치단체  충청북도 증평군    971     963        8  99.18
# 225  시도-지방자치단체  충청북도 진천군   1642    1641        1  99.94
# 226  시도-지방자치단체  충청북도 청주시  36664   36534      130  99.65
# 227  시도-지방자치단체  충청북도 충주시   3745    3725       20  99.47
#
# [228 rows x 6 columns]

# %%
df2_=df2[df2['유형']=='시도-지방자치단체'].reset_index(drop=True)
df2_
# Out:
#             유형       기관명     소계  기간내 처리  기간초과 처리     준수율
# 0    시도-지방자치단체   강원도 강릉시   6892    6792      100   98.55
# 1    시도-지방자치단체   강원도 고성군    586     565       21   96.42
# 2    시도-지방자치단체   강원도 동해시   2432    2404       28   98.85
# 3    시도-지방자치단체   강원도 삼척시   1538    1448       90   94.15
# 4    시도-지방자치단체   강원도 속초시   3356    3308       48   98.57
# ..         ...       ...    ...     ...      ...     ...
# 223  시도-지방자치단체  충청북도 제천시   2849    2836       13   99.54
# 224  시도-지방자치단체  충청북도 증평군   1324    1318        6   99.55
# 225  시도-지방자치단체  충청북도 진천군   2308    2308        0  100.00
# 226  시도-지방자치단체  충청북도 청주시  44091   44034       57   99.87
# 227  시도-지방자치단체  충청북도 충주시   5468    5421       47   99.14
#
# [228 rows x 6 columns]

# %%
df2_.rename(columns={'소계':'계'},inplace=True)
df2_
# Out:
#             유형       기관명      계  기간내 처리  기간초과 처리     준수율
# 0    시도-지방자치단체   강원도 강릉시   6892    6792      100   98.55
# 1    시도-지방자치단체   강원도 고성군    586     565       21   96.42
# 2    시도-지방자치단체   강원도 동해시   2432    2404       28   98.85
# 3    시도-지방자치단체   강원도 삼척시   1538    1448       90   94.15
# 4    시도-지방자치단체   강원도 속초시   3356    3308       48   98.57
# ..         ...       ...    ...     ...      ...     ...
# 223  시도-지방자치단체  충청북도 제천시   2849    2836       13   99.54
# 224  시도-지방자치단체  충청북도 증평군   1324    1318        6   99.55
# 225  시도-지방자치단체  충청북도 진천군   2308    2308        0  100.00
# 226  시도-지방자치단체  충청북도 청주시  44091   44034       57   99.87
# 227  시도-지방자치단체  충청북도 충주시   5468    5421       47   99.14
#
# [228 rows x 6 columns]

# %%
df3_=df3[df3['기관유형']=='시도-지방자치단체'].reset_index(drop=True)
df3_
# Out:
#           기관유형       기관명      계  기간내 처리  기간초과 처리  처리기간준수율
# 0    시도-지방자치단체   강원도 강릉시   7481    7431       50    99.33
# 1    시도-지방자치단체   강원도 고성군    866     791       75    91.34
# 2    시도-지방자치단체   강원도 동해시   2489    2440       49    98.03
# 3    시도-지방자치단체   강원도 삼척시   1481    1382       99    93.32
# 4    시도-지방자치단체   강원도 속초시   4386    4315       71    98.38
# ..         ...       ...    ...     ...      ...      ...
# 223  시도-지방자치단체  충청북도 제천시   3868    3858       10    99.74
# 224  시도-지방자치단체  충청북도 증평군   1133    1129        4    99.65
# 225  시도-지방자치단체  충청북도 진천군   2318    2310        8    99.65
# 226  시도-지방자치단체  충청북도 청주시  48510   48283      227    99.53
# 227  시도-지방자치단체  충청북도 충주시   5264    5234       30    99.43
#
# [228 rows x 6 columns]

# %%
df3_.rename(columns={'처리기간준수율':'준수율'},inplace=True)
df3_
# Out:
#           기관유형       기관명      계  기간내 처리  기간초과 처리    준수율
# 0    시도-지방자치단체   강원도 강릉시   7481    7431       50  99.33
# 1    시도-지방자치단체   강원도 고성군    866     791       75  91.34
# 2    시도-지방자치단체   강원도 동해시   2489    2440       49  98.03
# 3    시도-지방자치단체   강원도 삼척시   1481    1382       99  93.32
# 4    시도-지방자치단체   강원도 속초시   4386    4315       71  98.38
# ..         ...       ...    ...     ...      ...    ...
# 223  시도-지방자치단체  충청북도 제천시   3868    3858       10  99.74
# 224  시도-지방자치단체  충청북도 증평군   1133    1129        4  99.65
# 225  시도-지방자치단체  충청북도 진천군   2318    2310        8  99.65
# 226  시도-지방자치단체  충청북도 청주시  48510   48283      227  99.53
# 227  시도-지방자치단체  충청북도 충주시   5264    5234       30  99.43
#
# [228 rows x 6 columns]

# %%
df4_=df4[df4['유형']=='시도-지방자치단체'].reset_index(drop=True)
df4_
# Out:
#             유형       기관명     소계  기간내 처리  기간초과 처리    준수율
# 0    시도-지방자치단체   강원도 강릉시   6025    5956       69  98.85
# 1    시도-지방자치단체   강원도 고성군    521     495       26  95.01
# 2    시도-지방자치단체   강원도 동해시   2039    2003       36  98.23
# 3    시도-지방자치단체   강원도 삼척시   1163    1132       31  97.33
# 4    시도-지방자치단체   강원도 속초시   2518    2468       50  98.01
# ..         ...       ...    ...     ...      ...    ...
# 223  시도-지방자치단체  충청북도 제천시   3455    3454        1  99.97
# 224  시도-지방자치단체  충청북도 증평군    854     850        4  99.53
# 225  시도-지방자치단체  충청북도 진천군   2483    2480        3  99.88
# 226  시도-지방자치단체  충청북도 청주시  51034   50406      628  98.77
# 227  시도-지방자치단체  충청북도 충주시   5515    5493       22  99.60
#
# [228 rows x 6 columns]

# %%
df4_.rename(columns={'소계':'계'},inplace=True)
df4_
# Out:
#             유형       기관명      계  기간내 처리  기간초과 처리    준수율
# 0    시도-지방자치단체   강원도 강릉시   6025    5956       69  98.85
# 1    시도-지방자치단체   강원도 고성군    521     495       26  95.01
# 2    시도-지방자치단체   강원도 동해시   2039    2003       36  98.23
# 3    시도-지방자치단체   강원도 삼척시   1163    1132       31  97.33
# 4    시도-지방자치단체   강원도 속초시   2518    2468       50  98.01
# ..         ...       ...    ...     ...      ...    ...
# 223  시도-지방자치단체  충청북도 제천시   3455    3454        1  99.97
# 224  시도-지방자치단체  충청북도 증평군    854     850        4  99.53
# 225  시도-지방자치단체  충청북도 진천군   2483    2480        3  99.88
# 226  시도-지방자치단체  충청북도 청주시  51034   50406      628  98.77
# 227  시도-지방자치단체  충청북도 충주시   5515    5493       22  99.60
#
# [228 rows x 6 columns]

# %%
del df1_['기관유형']
del df2_['유형']
del df3_['기관유형']
del df4_['유형']

# %%
df=pd.concat([df1_,df2_,df3_,df4_]).reset_index(drop=True)
df
# Out:
#           기관명      계  기간내 처리  기간초과 처리    준수율
# 0     강원도 강릉시   4046    3953       93  97.70
# 1     강원도 고성군    387     375       12  96.90
# 2     강원도 동해시   1877    1831       46  97.55
# 3     강원도 삼척시   1462    1394       68  95.35
# 4     강원도 속초시   2229    2133       96  95.69
# ..        ...    ...     ...      ...    ...
# 907  충청북도 제천시   3455    3454        1  99.97
# 908  충청북도 증평군    854     850        4  99.53
# 909  충청북도 진천군   2483    2480        3  99.88
# 910  충청북도 청주시  51034   50406      628  98.77
# 911  충청북도 충주시   5515    5493       22  99.60
#
# [912 rows x 5 columns]

# %%
test=pd.DataFrame(df[['계','기간내 처리','기간초과 처리','기관명']].groupby('기관명').sum())
test
# Out:
#                계  기간내 처리  기간초과 처리
# 기관명
# 강원도 강릉시    24444   24132      312
# 강원도 고성군     2360    2226      134
# 강원도 동해시     8837    8678      159
# 강원도 삼척시     5644    5356      288
# 강원도 속초시    12489   12224      265
# ...          ...     ...      ...
# 충청북도 제천시   12327   12302       25
# 충청북도 증평군    4282    4260       22
# 충청북도 진천군    8751    8739       12
# 충청북도 청주시  180299  179257     1042
# 충청북도 충주시   19992   19873      119
#
# [228 rows x 3 columns]

# %%
mean_=pd.DataFrame(df[['준수율','기관명']].groupby('기관명').mean())
mean_
# Out:
#               준수율
# 기관명
# 강원도 강릉시   98.6075
# 강원도 고성군   94.9175
# 강원도 동해시   98.1650
# 강원도 삼척시   95.0375
# 강원도 속초시   97.6625
# ...           ...
# 충청북도 제천시  99.8000
# 충청북도 증평군  99.4775
# 충청북도 진천군  99.8675
# 충청북도 청주시  99.4550
# 충청북도 충주시  99.4100
#
# [228 rows x 1 columns]

# %%
final=pd.merge(test,mean_,on='기관명')
final
# Out:
#                계  기간내 처리  기간초과 처리      준수율
# 기관명
# 강원도 강릉시    24444   24132      312  98.6075
# 강원도 고성군     2360    2226      134  94.9175
# 강원도 동해시     8837    8678      159  98.1650
# 강원도 삼척시     5644    5356      288  95.0375
# 강원도 속초시    12489   12224      265  97.6625
# ...          ...     ...      ...      ...
# 충청북도 제천시   12327   12302       25  99.8000
# 충청북도 증평군    4282    4260       22  99.4775
# 충청북도 진천군    8751    8739       12  99.8675
# 충청북도 청주시  180299  179257     1042  99.4550
# 충청북도 충주시   19992   19873      119  99.4100
#
# [228 rows x 4 columns]

# %%
final.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/민원건수.csv')

# %% [markdown]
# # 시도 정리

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/민원건수.csv')
df
# Out:
#           기관명       계  기간내 처리  기간초과 처리      준수율
# 0     강원도 강릉시   24444   24132      312  98.6075
# 1     강원도 고성군    2360    2226      134  94.9175
# 2     강원도 동해시    8837    8678      159  98.1650
# 3     강원도 삼척시    5644    5356      288  95.0375
# 4     강원도 속초시   12489   12224      265  97.6625
# ..        ...     ...     ...      ...      ...
# 223  충청북도 제천시   12327   12302       25  99.8000
# 224  충청북도 증평군    4282    4260       22  99.4775
# 225  충청북도 진천군    8751    8739       12  99.8675
# 226  충청북도 청주시  180299  179257     1042  99.4550
# 227  충청북도 충주시   19992   19873      119  99.4100
#
# [228 rows x 5 columns]

# %%
sido=list(df['기관명'].apply(lambda x:x.split(' ')[0]))
sgg=list(df['기관명'].apply(lambda x:x.split(' ')[1]))

# %%
fin=pd.DataFrame({'시도':sido,'시군구':sgg})
fin['계']=df['계']
fin
# Out:
#        시도  시군구       계
# 0     강원도  강릉시   24444
# 1     강원도  고성군    2360
# 2     강원도  동해시    8837
# 3     강원도  삼척시    5644
# 4     강원도  속초시   12489
# ..    ...  ...     ...
# 223  충청북도  제천시   12327
# 224  충청북도  증평군    4282
# 225  충청북도  진천군    8751
# 226  충청북도  청주시  180299
# 227  충청북도  충주시   19992
#
# [228 rows x 3 columns]

# %%
fin.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/민원_최종.csv')
