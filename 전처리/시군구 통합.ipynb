# %%
sido_dic={'강원도':'강원','강원특별자치도':'강원','경기도':'경기','경상남도':'경남','경상북도':'경북','광주광역시':'광주','대구광역시':'대구',
          '대전광역시':'대전','서울특별시':'서울','전라남도':'전남','전라북도':'전북','전북특별자지도':'전북','전북특별자치도':'전북','제주특별자치도':'제주',
          '충청남도':'충남','충청북도':'충북','부산광역시':'부산','인천광역시':'인천','울산광역시':'울산','세종특별자치시':'세종'}

# %%
import pandas as pd

# %% [markdown]
# # 투입요소

# %% [markdown]
# ### 공무원 수

# %%
off=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022_공무원수_통합.csv')
off
# Out:
#           시도      시군구         전체        일반직  특정직  정무직  별정직    년도
# 0      서울특별시    서울특별시  11,254.00  10,692.00  524    6   32  2022
# 1      서울특별시      종로구   1,292.00   1,285.00    0    1    6  2022
# 2      서울특별시       중구   1,231.00   1,224.00    0    1    6  2022
# 3      서울특별시      용산구   1,318.00   1,310.00    0    1    7  2022
# 4      서울특별시      성동구   1,329.00   1,322.00    0    1    6  2022
# ..       ...      ...        ...        ...  ...  ...  ...   ...
# 240     경상남도      거창군        778        776    0    1    1  2022
# 241     경상남도      합천군        784        783    0    1    0  2022
# 242  제주특별자치도  제주특별자치도   2,330.00   2,160.00  151    4   15  2022
# 243  제주특별자치도      제주시   1,699.00   1,695.00    3    0    1  2022
# 244  제주특별자치도     서귀포시   1,200.00   1,197.00    2    0    1  2022
#
# [245 rows x 8 columns]

# %%
sd=list(off['시도'].unique())
offi=off[~ off['시군구'].isin(sd)].reset_index(drop=True) # 본청 제외
offi=pd.concat([offi,off[off['시도']=='세종특별자치시']],axis=0).reset_index(drop=True) # 단, 세종은 제외하지 않음.
offi
# Out:
#           시도      시군구        전체       일반직  특정직  정무직  별정직    년도
# 0      서울특별시      종로구  1,292.00  1,285.00    0    1    6  2022
# 1      서울특별시       중구  1,231.00  1,224.00    0    1    6  2022
# 2      서울특별시      용산구  1,318.00  1,310.00    0    1    7  2022
# 3      서울특별시      성동구  1,329.00  1,322.00    0    1    6  2022
# 4      서울특별시      광진구  1,422.00  1,416.00    0    1    5  2022
# ..       ...      ...       ...       ...  ...  ...  ...   ...
# 224     경상남도      거창군       778       776    0    1    1  2022
# 225     경상남도      합천군       784       783    0    1    0  2022
# 226  제주특별자치도      제주시  1,699.00  1,695.00    3    0    1  2022
# 227  제주특별자치도     서귀포시  1,200.00  1,197.00    2    0    1  2022
# 228  세종특별자치시  세종특별자치시  1,873.00  1,864.00    0    2    7  2022
#
# [229 rows x 8 columns]

# %%
offi['new_시도']=offi['시도'].apply(lambda x:sido_dic[x])
offi_fin=offi[['new_시도','시군구','전체']]
offi_fin.rename(columns={'new_시도':'시도'},inplace=True)
offi_fin['전체']=offi_fin['전체'].apply(lambda x:x.replace(',','')).astype(float)
offi_fin
# Out:
# <ipython-input-235-25c9677842b6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offi_fin.rename(columns={'new_시도':'시도'},inplace=True)
# <ipython-input-235-25c9677842b6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offi_fin['전체']=offi_fin['전체'].apply(lambda x:x.replace(',','')).astype(float)
#      시도      시군구      전체
# 0    서울      종로구  1292.0
# 1    서울       중구  1231.0
# 2    서울      용산구  1318.0
# 3    서울      성동구  1329.0
# 4    서울      광진구  1422.0
# ..   ..      ...     ...
# 224  경남      거창군   778.0
# 225  경남      합천군   784.0
# ...

# %%
offi_fin['전체']=offi_fin['전체'].astype(int)
# Out:
# <ipython-input-236-9e738e5fd6b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   offi_fin['전체']=offi_fin['전체'].astype(int)

# %%
of_sido=list(offi_fin['시도'].unique())
print(f'시도 개수: {len(of_sido)}')
of_sgg=dict()
for sd in of_sido:
  of_sgg[sd]=list(offi_fin[offi_fin['시도']==sd]['시군구'].unique())
for sd in of_sgg:
  print(f'{sd}: {len(of_sgg[sd])}')
# Out:
# 시도 개수: 17
# 서울: 25
# 부산: 16
# 대구: 8
# 인천: 10
# 광주: 5
# 대전: 5
# 울산: 5
# 경기: 31
# 강원: 18
# 충북: 11
# 충남: 15
# 전북: 14
# 전남: 22
# 경북: 23
# 경남: 18
# 제주: 2
# 세종: 1

# %% [markdown]
# ### 세출액

# %%
money=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/주민1인당세출예산액.csv')
money
# Out:
#       No  회계연도 지역명   자치단체코드  자치단체명   주민1인당 세출예산액   일반회계 세출예산액      인구수
# 0      1  2022  서울  1100000   서울본청   3295.924946  31342459847  9509458
# 1      2  2022  서울  1111000  서울종로구   3168.921394    458489054   144683
# 2      3  2022  서울  1112000   서울중구   4275.860946    523788690   122499
# 3      4  2022  서울  1113000  서울용산구   2467.209860    550071840   222953
# 4      5  2022  서울  1114000  서울성동구   2249.706721    643393625   285990
# ..   ...   ...  ..      ...    ...           ...          ...      ...
# 238  239  2022  경남  4877000  경남산청군  16175.213882    555780349    34360
# 239  240  2022  경남  4878000  경남함양군  13785.888489    528137388    38310
# 240  241  2022  경남  4879000  경남거창군  10438.520737    637511777    61073
# 241  242  2022  경남  4880000  경남합천군  14798.822755    635387455    42935
# 242  243  2022  제주  4900000   제주본청   7909.316702   5352701262   676759
#
# [243 rows x 8 columns]

# %%
money_=money[['지역명','자치단체명','주민1인당 세출예산액','인구수']]
money_.rename(columns={'지역명':'시도','자치단체명':'시군구'},inplace=True)
money_
# Out:
# <ipython-input-239-8ac5442613c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   money_.rename(columns={'지역명':'시도','자치단체명':'시군구'},inplace=True)
#      시도    시군구   주민1인당 세출예산액      인구수
# 0    서울   서울본청   3295.924946  9509458
# 1    서울  서울종로구   3168.921394   144683
# 2    서울   서울중구   4275.860946   122499
# 3    서울  서울용산구   2467.209860   222953
# 4    서울  서울성동구   2249.706721   285990
# ..   ..    ...           ...      ...
# 238  경남  경남산청군  16175.213882    34360
# 239  경남  경남함양군  13785.888489    38310
# 240  경남  경남거창군  10438.520737    61073
# 241  경남  경남합천군  14798.822755    42935
# 242  제주   제주본청   7909.316702   676759
#
# [243 rows x 4 columns]

# %%
# money_[money_['시도']=='경남']['시군구'].apply(lambda x:x.replace('경남',''))
money_['시군구']=money_['시군구'].apply(lambda x:x[2:])
money_
# Out:
# <ipython-input-240-bc86a5dd077d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   money_['시군구']=money_['시군구'].apply(lambda x:x[2:])
#      시도  시군구   주민1인당 세출예산액      인구수
# 0    서울   본청   3295.924946  9509458
# 1    서울  종로구   3168.921394   144683
# 2    서울   중구   4275.860946   122499
# 3    서울  용산구   2467.209860   222953
# 4    서울  성동구   2249.706721   285990
# ..   ..  ...           ...      ...
# 238  경남  산청군  16175.213882    34360
# 239  경남  함양군  13785.888489    38310
# 240  경남  거창군  10438.520737    61073
# 241  경남  합천군  14798.822755    42935
# 242  제주   본청   7909.316702   676759
#
# [243 rows x 4 columns]

# %%
money_fin=money_[money_['시군구']!='본청'].reset_index(drop=True)
money_fin
# Out:
#      시도  시군구   주민1인당 세출예산액     인구수
# 0    서울  종로구   3168.921394  144683
# 1    서울   중구   4275.860946  122499
# 2    서울  용산구   2467.209860  222953
# 3    서울  성동구   2249.706721  285990
# 4    서울  광진구   2038.762638  339996
# ..   ..  ...           ...     ...
# 221  경남  하동군  14716.024742   43449
# 222  경남  산청군  16175.213882   34360
# 223  경남  함양군  13785.888489   38310
# 224  경남  거창군  10438.520737   61073
# 225  경남  합천군  14798.822755   42935
#
# [226 rows x 4 columns]

# %%
mn_sido=list(money_fin['시도'].unique())
print(f'시도 개수: {len(mn_sido)}')
mn_sgg=dict()
for sd in mn_sido:
  mn_sgg[sd]=list(money_fin[money_fin['시도']==sd]['시군구'].unique())
for sd in mn_sido:
  print(f'{sd}: {len(mn_sgg[sd])}')
# Out:
# 시도 개수: 15
# 서울: 25
# 부산: 16
# 대구: 8
# 인천: 10
# 광주: 5
# 대전: 5
# 울산: 5
# 경기: 31
# 강원: 18
# 충북: 11
# 충남: 15
# 전북: 14
# 전남: 22
# 경북: 23
# 경남: 18

# %% [markdown]
# - 제주, 세종 없음 (세출예산액, 인구수)

# %%
# https://www.lofin365.go.kr/portal/LF5110000.do?pdtaId=E8CLIL7H1FHQ3F38ON5W225441&rdIncrYn=Y&frstParamYn=Y
# 제주 본청: (7909, 676789) # /2하
# 세종 본청: (4249, 371895)

# - 서귀포시 5월 인구 : 184,491명 # 0.3
#  - 제주도 5월 인구 : 677,766명 # 0.7

# %%
sj=money[money['자치단체명']=='세종본청']
sj_fin=pd.DataFrame({'시도':['세종'],'시군구':['세종'],
                     '주민1인당 세출예산액':sj['주민1인당 세출예산액'],'인구수':sj['인구수']})
sj_fin
# Out:
#     시도 시군구  주민1인당 세출예산액     인구수
# 81  세종  세종  4248.875005  371895

# %%
jeju=money[money['자치단체명']=='제주본청'].reset_index(drop=True)
money=jeju['주민1인당 세출예산액'][0]
people=jeju['인구수'][0]

# %%
tot=money*people
# [제주시, 서귀포시]
peo=[int(people*0.7), int(people*0.3)]
mon=[round(tot/peo[0],6),round(tot/peo[1],6)]
print(peo)
print(mon)
# Out:
# [473731, 203027]
# [11299.031015, 26364.479907]

# %%
jeju_fin=pd.DataFrame({'시도':['제주' for _ in range(2)],'시군구':['제주시','서귀포시'],
                     '주민1인당 세출예산액':mon,'인구수':peo})
jeju_fin
# Out:
#    시도   시군구   주민1인당 세출예산액     인구수
# 0  제주   제주시  11299.031015  473731
# 1  제주  서귀포시  26364.479907  203027

# %%
money_final=pd.concat([money_fin,sj_fin,jeju_fin],axis=0).reset_index(drop=True)
money_final
# Out:
#      시도   시군구   주민1인당 세출예산액     인구수
# 0    서울   종로구   3168.921394  144683
# 1    서울    중구   4275.860946  122499
# 2    서울   용산구   2467.209860  222953
# 3    서울   성동구   2249.706721  285990
# 4    서울   광진구   2038.762638  339996
# ..   ..   ...           ...     ...
# 224  경남   거창군  10438.520737   61073
# 225  경남   합천군  14798.822755   42935
# 226  세종    세종   4248.875005  371895
# 227  제주   제주시  11299.031015  473731
# 228  제주  서귀포시  26364.479907  203027
#
# [229 rows x 4 columns]

# %%
mn_sido=list(money_final['시도'].unique())
print(f'시도 개수: {len(mn_sido)}')
mn_sgg=dict()
for sd in mn_sido:
  mn_sgg[sd]=list(money_final[money_final['시도']==sd]['시군구'].unique())
for sd in mn_sido:
  print(f'{sd}: {len(mn_sgg[sd])}')
# Out:
# 시도 개수: 17
# 서울: 25
# 부산: 16
# 대구: 8
# 인천: 10
# 광주: 5
# 대전: 5
# 울산: 5
# 경기: 31
# 강원: 18
# 충북: 11
# 충남: 15
# 전북: 14
# 전남: 22
# 경북: 23
# 경남: 18
# 세종: 1
# 제주: 2

# %%
offi_sort=offi_fin.sort_values(by=['시도','시군구']).reset_index(drop=True)
offi_sort.rename(columns={'전체':'공무원수'},inplace=True)
offi_sort
# Out:
#      시도  시군구  공무원수
# 0    강원  강릉시  1481
# 1    강원  고성군   547
# 2    강원  동해시   705
# 3    강원  삼척시   886
# 4    강원  속초시   704
# ..   ..  ...   ...
# 224  충북  제천시  1244
# 225  충북  증평군   470
# 226  충북  진천군   818
# 227  충북  청주시  3292
# 228  충북  충주시  1483
#
# [229 rows x 3 columns]

# %%
money_sort=money_final.sort_values(by=['시도','시군구']).reset_index(drop=True)
money_sort
# Out:
#      시도  시군구   주민1인당 세출예산액     인구수
# 0    강원  강릉시   5594.350790  212965
# 1    강원  고성군  14064.505340   27249
# 2    강원  동해시   4992.227307   90081
# 3    강원  삼척시   9015.543442   63429
# 4    강원  속초시   4949.341341   82791
# ..   ..  ...           ...     ...
# 224  충북  제천시   6769.078075  131591
# 225  충북  증평군   6671.725636   36426
# 226  충북  진천군   6276.415692   85176
# 227  충북  청주시   3042.843402  848482
# 228  충북  충주시   5021.350944  209358
#
# [229 rows x 4 columns]

# %%
off_num=offi_sort['공무원수']/(money_sort['인구수']/1000) # 인구 천명당 공무원 수
off_num
# Out:
# 0       6.954194
# 1      20.074131
# 2       7.826290
# 3      13.968374
# 4       8.503340
#          ...
# 224     9.453534
# 225    12.902872
# 226     9.603644
# 227     3.879870
# 228     7.083560
# Length: 229, dtype: float64

# %% [markdown]
# ### Merge

# %%
inputs=pd.merge(money_sort,offi_sort,on=['시도','시군구'],how='left')[['시도','시군구','주민1인당 세출예산액']]
# inputs=pd.concat([offi_sort,money_sort],axis=1)[['시도','시군구','주민1인당 세출예산액']]
inputs['천명당 공무원수']=off_num
inputs
# Out:
#      시도  시군구   주민1인당 세출예산액   천명당 공무원수
# 0    강원  강릉시   5594.350790   6.954194
# 1    강원  고성군  14064.505340  20.074131
# 2    강원  동해시   4992.227307   7.826290
# 3    강원  삼척시   9015.543442  13.968374
# 4    강원  속초시   4949.341341   8.503340
# ..   ..  ...           ...        ...
# 224  충북  제천시   6769.078075   9.453534
# 225  충북  증평군   6671.725636  12.902872
# 226  충북  진천군   6276.415692   9.603644
# 227  충북  청주시   3042.843402   3.879870
# 228  충북  충주시   5021.350944   7.083560
#
# [229 rows x 4 columns]

# %%
inputs.isna().sum()
# Out:
# 시도             0
# 시군구            0
# 주민1인당 세출예산액    0
# 천명당 공무원수       0
# dtype: int64

# %% [markdown]
# # 산출요소

# %% [markdown]
# ### 민원

# %%
mw=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/민원_최종.csv')[['시도','시군구','계']]
mw
# Out:
#        시도  시군구       계
# 0     강원도  강릉시   24444
# 1     강원도  고성군    2360
# 2     강원도  동해시    8837
# 3     강원도  삼척시    5644
# 4     강원도  속초시   12489
# ..    ...  ...     ...
# 223  충청북도  제천시   12327
# 224  충청북도  증평군    4282
# 225  충청북도  진천군    8751
# 226  충청북도  청주시  180299
# 227  충청북도  충주시   19992
#
# [228 rows x 3 columns]

# %%
mw['시도']=mw['시도'].apply(lambda x:sido_dic[x])
mw.rename(columns={'계':'민원건수'},inplace=True)
mw
# Out:
#      시도  시군구    민원건수
# 0    강원  강릉시   24444
# 1    강원  고성군    2360
# 2    강원  동해시    8837
# 3    강원  삼척시    5644
# 4    강원  속초시   12489
# ..   ..  ...     ...
# 223  충북  제천시   12327
# 224  충북  증평군    4282
# 225  충북  진천군    8751
# 226  충북  청주시  180299
# 227  충북  충주시   19992
#
# [228 rows x 3 columns]

# %%
mw_sido=list(mw['시도'].unique())
print(f'시도 개수: {len(mw_sido)}')
mw_sgg=dict()
for sd in mw_sido:
  mw_sgg[sd]=list(mw[mw['시도']==sd]['시군구'].unique())
for sd in mw_sido:
  print(f'{sd}: {len(mw_sgg[sd])}')
# Out:
# 시도 개수: 16
# 강원: 18
# 경기: 31
# 경남: 18
# 경북: 23
# 광주: 5
# 대구: 8
# 대전: 5
# 부산: 16
# 서울: 25
# 울산: 5
# 인천: 10
# 전남: 22
# 전북: 14
# 제주: 2
# 충남: 15
# 충북: 11

# %% [markdown]
# - 세종 없음: row data에도 없음 -> 평균값 사용

# %%
sj=int(mw['민원건수'].mean())
t=pd.DataFrame([['세종','세종',sj]],columns=['시도','시군구','민원건수'])
mw_final=pd.concat([mw,t],axis=0,ignore_index=True)
mw_final=mw_final.sort_values(['시도','시군구']).reset_index(drop=True)
mw_final
# Out:
#      시도  시군구    민원건수
# 0    강원  강릉시   24444
# 1    강원  고성군    2360
# 2    강원  동해시    8837
# 3    강원  삼척시    5644
# 4    강원  속초시   12489
# ..   ..  ...     ...
# 224  충북  제천시   12327
# 225  충북  증평군    4282
# 226  충북  진천군    8751
# 227  충북  청주시  180299
# 228  충북  충주시   19992
#
# [229 rows x 3 columns]

# %%
outputs=mw_final

# %% [markdown]
# ### 건축허가 면적

# %%
arch=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/건축_최종.csv')
arch
# Out:
#           시도          시군구    total
# 0      서울특별시        서울특별시   726649
# 1      서울특별시       서울시강남구  1500991
# 2      서울특별시       서울시강동구   381435
# 3      서울특별시       서울시강북구   176429
# 4      서울특별시       서울시강서구  1151293
# ..       ...          ...      ...
# 272     경상남도       창원시의창구   133639
# 273     경상남도       창원시진해구   101993
# 274  제주특별자치도      제주특별자치도     3001
# 275  제주특별자치도  제주특별자치도서귀포시   764187
# 276  제주특별자치도   제주특별자치도제주시  1873549
#
# [277 rows x 3 columns]

# %%
sj=arch[arch['시도']=='세종특별자치시']
sj
# Out:
#          시도      시군구    total
# 81  세종특별자치시  세종특별자치시  1247607

# %%
sido=list(arch['시도'].unique())
sido
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
archi=arch[~ arch['시군구'].isin(sido)]
archi
# Out:
#           시도          시군구    total
# 1      서울특별시       서울시강남구  1500991
# 2      서울특별시       서울시강동구   381435
# 3      서울특별시       서울시강북구   176429
# 4      서울특별시       서울시강서구  1151293
# 5      서울특별시       서울시관악구   361113
# ..       ...          ...      ...
# 271     경상남도       창원시성산구   169636
# 272     경상남도       창원시의창구   133639
# 273     경상남도       창원시진해구   101993
# 275  제주특별자치도  제주특별자치도서귀포시   764187
# 276  제주특별자치도   제주특별자치도제주시  1873549
#
# [260 rows x 3 columns]

# %%
archi_=pd.concat([archi,sj],axis=0).reset_index(drop=True)
archi_
# Out:
#           시도          시군구    total
# 0      서울특별시       서울시강남구  1500991
# 1      서울특별시       서울시강동구   381435
# 2      서울특별시       서울시강북구   176429
# 3      서울특별시       서울시강서구  1151293
# 4      서울특별시       서울시관악구   361113
# ..       ...          ...      ...
# 256     경상남도       창원시의창구   133639
# 257     경상남도       창원시진해구   101993
# 258  제주특별자치도  제주특별자치도서귀포시   764187
# 259  제주특별자치도   제주특별자치도제주시  1873549
# 260  세종특별자치시      세종특별자치시  1247607
#
# [261 rows x 3 columns]

# %%
archi_['시도']=archi_['시도'].apply(lambda x:sido_dic[x])

# %%
archi_
# Out:
#      시도          시군구    total
# 0    서울       서울시강남구  1500991
# 1    서울       서울시강동구   381435
# 2    서울       서울시강북구   176429
# 3    서울       서울시강서구  1151293
# 4    서울       서울시관악구   361113
# ..   ..          ...      ...
# 256  경남       창원시의창구   133639
# 257  경남       창원시진해구   101993
# 258  제주  제주특별자치도서귀포시   764187
# 259  제주   제주특별자치도제주시  1873549
# 260  세종      세종특별자치시  1247607
#
# [261 rows x 3 columns]

# %%
sgg=[]
sgg.extend(list(archi_[archi_['시도']=='서울']['시군구'].apply(lambda x:x.replace('서울시',''))))
sgg.extend(list(archi_[archi_['시도']=='부산']['시군구'].apply(lambda x:x.replace('부산시',''))))
sgg.extend(list(archi_[archi_['시도']=='대구']['시군구'].apply(lambda x:x.replace('대구시',''))))
sgg.extend(list(archi_[archi_['시도']=='인천']['시군구'].apply(lambda x:x.replace('인천시',''))))
sgg.extend(list(archi_[archi_['시도']=='광주']['시군구'].apply(lambda x:x.replace('광주시',''))))
sgg.extend(list(archi_[archi_['시도']=='대전']['시군구'].apply(lambda x:x.replace('대전시',''))))
sgg.extend(list(archi_[archi_['시도']=='울산']['시군구'].apply(lambda x:x.replace('울산시',''))))
sgg.extend(list(archi_[archi_['시도']=='경기']['시군구'].apply(lambda x:x.replace('경기',''))))
sgg.extend(list(archi_[archi_['시도']=='강원']['시군구'].apply(lambda x:x.replace('강원',''))))
sgg.extend(list(archi_[archi_['시도']=='충북']['시군구'].apply(lambda x:x.replace('충북',''))))
sgg.extend(list(archi_[archi_['시도']=='충남']['시군구'].apply(lambda x:x.replace('충남',''))))
sgg.extend(list(archi_[archi_['시도']=='전북']['시군구'].apply(lambda x:x.replace('전북',''))))
sgg.extend(list(archi_[archi_['시도']=='전남']['시군구'].apply(lambda x:x.replace('전남',''))))
sgg.extend(list(archi_[archi_['시도']=='경북']['시군구'].apply(lambda x:x.replace('경북',''))))
sgg.extend(list(archi_[archi_['시도']=='경남']['시군구'].apply(lambda x:x.replace('경남',''))))
sgg.extend(list(archi_[archi_['시도']=='제주']['시군구'].apply(lambda x:x.replace('제주특별자치도',''))))
sgg.append('세종시')
# sgg

# %%
len(sgg)
# Out:
# 261

# %%
archi_['시군구']=sgg

# %%
ar_sido=list(archi_['시도'].unique())
print(f'시도 개수: {len(ar_sido)}')
ar_sgg=dict()
for sd in ar_sido:
  ar_sgg[sd]=list(archi_[archi_['시도']==sd]['시군구'].unique())
for sd in ar_sido:
  print(f'{sd}: {len(ar_sgg[sd])}')
# 경기: 31 V
# 충북: 11 V
# 충남: 15 V
# 전북: 14 V
# 경북: 23 V
# 경남: 18 V
# Out:
# 시도 개수: 17
# 서울: 25
# 부산: 16
# 대구: 8
# 인천: 10
# 광주: 5
# 대전: 5
# 울산: 5
# 경기: 48
# 강원: 18
# 충북: 15
# 충남: 17
# 전북: 16
# 전남: 22
# 경북: 25
# 경남: 23
# 제주: 2
# 세종: 1

# %%
# mw_sgg['경남']

# %%
archi_[archi_['시도']=='경남']['시군구']
# Out:
# 235         거제시
# 236         거창군
# 237         고성군
# 238         김해시
# 239         남해군
# 240         밀양시
# 241         사천시
# 242         산청군
# 243         양산시
# 244         의령군
# 245         진주시
# 246         창녕군
# 247         창원시
# 248         통영시
# 249         하동군
# 250         함안군
# 251         함양군
# 252         합천군
# 253    창원시마산합포구
# 254    창원시마산회원구
# 255      창원시성산구
# 256      창원시의창구
# 257      창원시진해구
# Name: 시군구, dtype: object

# %%
 # 제외할 친구들
# 경기: 105 ~ 121
# 충북: 140 ~ 143
# 충남: 155 ~ 156
# 전북: 186 ~ 187
# 경북: 233 ~ 234
# 경남: 253 ~ 257

sub=[i for i in range(105,122)]
sub.extend([i for i in range(140,144)])
sub.extend([i for i in range(155,157)])
sub.extend([i for i in range(186,188)])
sub.extend([i for i in range(233,235)])
sub.extend([i for i in range(253,258)])
# sub

# %%
test=archi_.reset_index()
archite=test[~ test['index'].isin(sub)][['시도','시군구','total']].reset_index(drop=True)
archite
# Out:
#      시도   시군구    total
# 0    서울   강남구  1500991
# 1    서울   강동구   381435
# 2    서울   강북구   176429
# 3    서울   강서구  1151293
# 4    서울   관악구   361113
# ..   ..   ...      ...
# 224  경남   함양군   155766
# 225  경남   합천군   113338
# 226  제주  서귀포시   764187
# 227  제주   제주시  1873549
# 228  세종   세종시  1247607
#
# [229 rows x 3 columns]

# %%
archite
archite.rename(columns={'total':'건축허가 면적'},inplace=True)
archite
# Out:
#      시도   시군구  건축허가 면적
# 0    서울   강남구  1500991
# 1    서울   강동구   381435
# 2    서울   강북구   176429
# 3    서울   강서구  1151293
# 4    서울   관악구   361113
# ..   ..   ...      ...
# 224  경남   함양군   155766
# 225  경남   합천군   113338
# 226  제주  서귀포시   764187
# 227  제주   제주시  1873549
# 228  세종   세종시  1247607
#
# [229 rows x 3 columns]

# %%
ar_sido=list(archite['시도'].unique())
print(f'시도 개수: {len(ar_sido)}')
ar_sgg=dict()
for sd in ar_sido:
  ar_sgg[sd]=list(archite[archite['시도']==sd]['시군구'].unique())
for sd in ar_sido:
  print(f'{sd}: {len(ar_sgg[sd])}')
# Out:
# 시도 개수: 17
# 서울: 25
# 부산: 16
# 대구: 8
# 인천: 10
# 광주: 5
# 대전: 5
# 울산: 5
# 경기: 31
# 강원: 18
# 충북: 11
# 충남: 15
# 전북: 14
# 전남: 22
# 경북: 23
# 경남: 18
# 제주: 2
# 세종: 1

# %%
ar_sgg
# Out:
# {'서울': ['강남구',
#   '강동구',
#   '강북구',
#   '강서구',
#   '관악구',
#   '광진구',
#   '구로구',
#   '금천구',
#   '노원구',
#   '도봉구',
#   '동대문구',
#   '동작구',
#   '마포구',
#   '서대문구',
#   '서초구',
#   '성동구',
#   '성북구',
#   '송파구',
#   '양천구',
#   '영등포구',
#   '용산구',
#   '은평구',
#   '종로구',
#   '중구',
#   '중랑구'],
#  '부산': ['강서구',
#   '금정구',
#   '기장군',
#   '남구',
#   '동구',
#   '동래구',
#   '부산진구',
#   '북구',
#   '사상구',
#   '사하구',
#   '서구',
#   '수영구',
#   '연제구',
#   '영도구',
#   '중구',
#   '해운대구'],
#  '대구': ['남구', '달서구', '달성군', '동구', '북구', '서구', '수성구', '중구'],
#  '인천': ['강화군', '계양구', '남동구', '동구', '미추홀구', '부평구', '서구', '연수구', '옹진군', '중구'],
#  '광주': ['광산구', '남구', '동구', '북구', '서구'],
#  '대전': ['대덕구', '동구', '서구', '유성구', '중구'],
#  '울산': ['남구', '동구', '북구', '울주군', '중구'],
#  '경기': ['가평군',
#   '고양시',
#   '과천시',
#   '광명시',
#   '광주시',
#   '구리시',
#   '군포시',
#   '김포시',
#   '남양주시',
#   '동두천시',
#   '부천시',
#   '성남시',
#   '수원시',
#   '시흥시',
#   '안산시',
#   '안성시',
#   '안양시',
#   '양주시',
#   '양평군',
#   '여주시',
#   '연천군',
#   '오산시',
#   '용인시',
# ...

# %%
ar_final=archite.sort_values(by=['시도','시군구']).reset_index(drop=True)
ar_final
# Out:
#      시도  시군구  건축허가 면적
# 0    강원  강릉시   831434
# 1    강원  고성군   240614
# 2    강원  동해시   163638
# 3    강원  삼척시   130471
# 4    강원  속초시   629486
# ..   ..  ...      ...
# 224  충북  제천시   536522
# 225  충북  증평군    93140
# 226  충북  진천군   921726
# 227  충북  청주시  3712558
# 228  충북  충주시   877692
#
# [229 rows x 3 columns]

# %%
sj=int(ar_final[ar_final['시도']=='세종']['건축허가 면적'])
sj
# Out:
# 1247607

# %%
outputs=pd.merge(outputs,ar_final,on=['시도','시군구'],how='left')
outputs.isna().sum()
# inputs=pd.merge(money_sort,offi_sort,on=['시도','시군구'],how='left')[['시도','시군구','주민1인당 세출예산액']]
# inputs=pd.concat([offi_sort,money_sort],axis=1)[['시도','시군구','주민1인당 세출예산액']]
# inputs['천명당 공무원수']=off_num
# inputs
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    1
# dtype: int64

# %%
outputs.loc[outputs['건축허가 면적'].isna(),'건축허가 면적']=sj

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# dtype: int64

# %% [markdown]
# ### 도시공원 - 진행중
# - 와 공원 잘못 전처리했네...
# - 제외할 것

# %%
park=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/공원_최종.csv')[['제공기관명','공원면적']]
park
# Out:
#         제공기관명          공원면적
# 0     강원도 강릉시  1.188815e+06
# 1     강원도 고성군  2.692920e+05
# 2     강원도 동해시  4.127500e+04
# 3     강원도 삼척시  4.409960e+05
# 4     강원도 속초시  8.208620e+05
# ..        ...           ...
# 249  충청북도 제천시  5.787652e+05
# 250  충청북도 증평군  2.560390e+05
# 251  충청북도 진천군  8.411336e+05
# 252  충청북도 청주시  1.527697e+07
# 253  충청북도 충주시  3.006468e+06
#
# [254 rows x 2 columns]

# %%
test=list(park['제공기관명'].apply(lambda x:x.split(' ')))

for s in test:
  if len(s)!=2:
    print(s)
# sgg=
# park['제공기관명'].apply(lambda x:x.split(' ')[1])
# Out:
# ['광주광역시']
# ['기장군도시관리공단']
# ['대구광역시']
# ['부산관광공사']
# ['세종특별자치시']
# ['울산시설공단']
# ['인천광역시']
# ['인천시설공단']
# ['충청남도']

# %%
# sido_list

# %%
park_=park[~ park['제공기관명'].isin(['광주광역시','기장군도시관리공단','대구광역시','부산관광공사','울산시설공단','인천광역시','인천시설공단','충청남도'])].reset_index(drop=True)
park_
# Out:
#         제공기관명          공원면적
# 0     강원도 강릉시  1.188815e+06
# 1     강원도 고성군  2.692920e+05
# 2     강원도 동해시  4.127500e+04
# 3     강원도 삼척시  4.409960e+05
# 4     강원도 속초시  8.208620e+05
# ..        ...           ...
# 241  충청북도 제천시  5.787652e+05
# 242  충청북도 증평군  2.560390e+05
# 243  충청북도 진천군  8.411336e+05
# 244  충청북도 청주시  1.527697e+07
# 245  충청북도 충주시  3.006468e+06
#
# [246 rows x 2 columns]

# %%
sido=list(park_['제공기관명'].apply(lambda x:x.split(' ')[0]))
# sido

# %%
park_.loc[167,'제공기관명']='세종특별자치시 세종시'
park_.iloc[167]
# Out:
# 제공기관명    세종특별자치시 세종시
# 공원면적       3382224.0
# Name: 167, dtype: object

# %%
sgg=list(park_['제공기관명'].apply(lambda x:x.split(' ')[1]))
# sgg

# %%
len(sido)
# Out:
# 246

# %%
park_fin=pd.DataFrame({'시도':sido, '시군구':sgg})
park_fin['공원면적']=park_['공원면적']
park_fin
# Out:
#        시도  시군구          공원면적
# 0     강원도  강릉시  1.188815e+06
# 1     강원도  고성군  2.692920e+05
# 2     강원도  동해시  4.127500e+04
# 3     강원도  삼척시  4.409960e+05
# 4     강원도  속초시  8.208620e+05
# ..    ...  ...           ...
# 241  충청북도  제천시  5.787652e+05
# 242  충청북도  증평군  2.560390e+05
# 243  충청북도  진천군  8.411336e+05
# 244  충청북도  청주시  1.527697e+07
# 245  충청북도  충주시  3.006468e+06
#
# [246 rows x 3 columns]

# %%
park_fin['시도']=park_fin['시도'].apply(lambda x:sido_dic[x])
park_fin
# Out:
#      시도  시군구          공원면적
# 0    강원  강릉시  1.188815e+06
# 1    강원  고성군  2.692920e+05
# 2    강원  동해시  4.127500e+04
# 3    강원  삼척시  4.409960e+05
# 4    강원  속초시  8.208620e+05
# ..   ..  ...           ...
# 241  충북  제천시  5.787652e+05
# 242  충북  증평군  2.560390e+05
# 243  충북  진천군  8.411336e+05
# 244  충북  청주시  1.527697e+07
# 245  충북  충주시  3.006468e+06
#
# [246 rows x 3 columns]

# %%
park_final=pd.DataFrame(park_fin.groupby(['시도','시군구'])['공원면적'].sum()).reset_index()
park_final
# Out:
#      시도  시군구          공원면적
# 0    강원  강릉시  2.377630e+06
# 1    강원  고성군  5.385840e+05
# 2    강원  동해시  8.255000e+04
# 3    강원  삼척시  8.819920e+05
# 4    강원  속초시  1.641724e+06
# ..   ..  ...           ...
# 221  충북  제천시  5.787652e+05
# 222  충북  증평군  2.560390e+05
# 223  충북  진천군  8.411336e+05
# 224  충북  청주시  1.527697e+07
# 225  충북  충주시  3.006468e+06
#
# [226 rows x 3 columns]

# %%
pr_sido=list(park_final['시도'].unique())
print(f'시도 개수: {len(pr_sido)}')
pr_sgg=dict()
for sd in pr_sido:
  pr_sgg[sd]=list(park_final[park_final['시도']==sd]['시군구'].unique())
for sd in pr_sido:
  print(f'{sd}: {len(pr_sgg[sd])}')

# 대구: 8 V
# 인천: 10 V
# 광주: 5
# 충남: 15
# 전북: 14
# Out:
# 시도 개수: 17
# 강원: 18
# 경기: 31
# 경남: 18
# 경북: 23
# 광주: 4
# 대구: 9
# 대전: 5
# 부산: 16
# 서울: 25
# 세종: 1
# 울산: 5
# 인천: 9
# 전남: 22
# 전북: 13
# 제주: 2
# 충남: 14
# 충북: 11

# %%
park_final[park_final['시도']=='대구'] # 군위군 제외
park_final.drop([94],inplace=True)
park_final.iloc[94]
# Out:
# 시도           대구
# 시군구          남구
# 공원면적    57924.9
# Name: 95, dtype: object

# %%
park_final.reset_index(drop=True)
# Out:
#      시도  시군구          공원면적
# 0    강원  강릉시  2.377630e+06
# 1    강원  고성군  5.385840e+05
# 2    강원  동해시  8.255000e+04
# 3    강원  삼척시  8.819920e+05
# 4    강원  속초시  1.641724e+06
# ..   ..  ...           ...
# 220  충북  제천시  5.787652e+05
# 221  충북  증평군  2.560390e+05
# 222  충북  진천군  8.411336e+05
# 223  충북  청주시  1.527697e+07
# 224  충북  충주시  3.006468e+06
#
# [225 rows x 3 columns]

# %%
park_final[park_final['시도']=='인천'] # 옹진군
men=park_final[park_final['시도']=='인천']['공원면적'].median()
park_final.loc[226,:]=['인천','옹진군',men]
park_final
# Out:
#      시도  시군구        공원면적
# 0    강원  강릉시   2377629.6
# 1    강원  고성군    538584.0
# 2    강원  동해시     82550.0
# 3    강원  삼척시    881992.0
# 4    강원  속초시   1641724.0
# ..   ..  ...         ...
# 222  충북  증평군    256039.0
# 223  충북  진천군    841133.6
# 224  충북  청주시  15276973.7
# 225  충북  충주시   3006468.5
# 226  인천  옹진군    882258.0
#
# [226 rows x 3 columns]

# %%
park_final[park_final['시도']=='인천']
# Out:
#      시도   시군구         공원면적
# 155  인천   강화군   214506.000
# 156  인천   계양구   432295.703
# 157  인천   남동구  2191244.000
# 158  인천    동구   209376.000
# 159  인천  미추홀구   691613.100
# 160  인천   부평구   882258.000
# 161  인천    서구  1312727.900
# 162  인천   연수구   962264.800
# 163  인천    중구  1721422.000
# 226  인천   옹진군   882258.000

# %%
ar_sgg['인천']
# Out:
# ['강화군', '계양구', '남동구', '동구', '미추홀구', '부평구', '서구', '연수구', '옹진군', '중구']

# %%
men=park_final[park_final['시도']=='광주'].median() # 남구
# park_final.loc[227,:]=['광주','남구',men]
# Out:
# <ipython-input-61-61a2d1c6b682>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   men=park_final[park_final['시도']=='광주'].median() # 남구

# %%
# ar_sgg['광주']

# %% [markdown]
# ### 급수인구

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/급수인구_최종.csv',encoding='cp949')
df
# Out:
#              sido     ssg  people
# 0    강원특별자치도(강원도)     강릉시  205582
# 1    강원특별자치도(강원도)     고성군   20759
# 2    강원특별자치도(강원도)     동해시   89803
# 3    강원특별자치도(강원도)     삼척시   56421
# 4    강원특별자치도(강원도)     속초시   83552
# ..            ...     ...     ...
# 245          충청북도  청주시상당구  184901
# 246          충청북도  청주시서원구  195382
# 247          충청북도  청주시청원구  196306
# 248          충청북도  청주시흥덕구  267950
# 249          충청북도     충주시  199435
#
# [250 rows x 3 columns]

# %%
df['sido'].unique()
# Out:
# array(['강원특별자치도(강원도)', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시',
#        '부산광역시', '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도',
#        '제주특별자치도', '충청남도', '충청북도'], dtype=object)

# %%
sido_dic={'강원도':'강원','강원특별자치도':'강원','강원특별자치도(강원도)':'강원','경기도':'경기','경상남도':'경남','경상북도':'경북','광주광역시':'광주','대구광역시':'대구',
          '대전광역시':'대전','서울특별시':'서울','전라남도':'전남','전라북도':'전북','전북특별자치도':'전북','제주특별자치도':'제주',
          '충청남도':'충남','충청북도':'충북','부산광역시':'부산','인천광역시':'인천','울산광역시':'울산','세종특별자치시':'세종'}

# %%
df['sido']=df['sido'].apply(lambda x:sido_dic[x])

# %%
lst=list(df['sido'].unique())
lst
# Out:
# ['강원',
#  '경기',
#  '경남',
#  '경북',
#  '광주',
#  '대구',
#  '대전',
#  '부산',
#  '서울',
#  '세종',
#  '울산',
#  '인천',
#  '전남',
#  '전북',
#  '제주',
#  '충남',
#  '충북']

# %%
new=[]
ap=list(df[df['sido']==lst[1]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
    # print(a[:3])
  else:
    new.append(a)
new
# Out:
# ['가평군',
#  '고양시',
#  '고양시',
#  '고양시',
#  '과천시',
#  '광명시',
#  '광주시',
#  '구리시',
#  '군포시',
#  '김포시',
#  '남양주시',
#  '동두천시',
#  '부천시',
#  '성남시',
#  '성남시',
#  '성남시',
#  '수원시',
#  '수원시',
#  '수원시',
#  '수원시',
#  '시흥시',
#  '안산시',
#  '안산시',
#  '안성시',
#  '안양시',
#  '안양시',
#  '양주시',
#  '양평군',
#  '여주시',
#  '연천군',
#  '오산시',
#  '용인시',
#  '용인시',
#  '용인시',
#  '의왕시',
#  '의정부시',
#  '이천시',
#  '파주시',
#  '평택시',
#  '포천시',
#  '하남시',
#  '화성시']

# %%
df.loc[df['sido']==lst[1],'ssg']=new

# %%
df[df['sido']==lst[1]]
# Out:
#    sido   ssg  people
# 18   경기   가평군   52960
# 19   경기   고양시  479725
# 20   경기   고양시  302838
# 21   경기   고양시  304504
# 22   경기   과천시   72883
# 23   경기   광명시  292893
# 24   경기   광주시  371174
# 25   경기   구리시  193817
# 26   경기   군포시  265849
# 27   경기   김포시  479624
# 28   경기  남양주시  723816
# 29   경기  동두천시   93592
# 30   경기   부천시  831846
# 31   경기   성남시  484183
# 32   경기   성남시  235988
# 33   경기   성남시  210777
# 34   경기   수원시  364136
# 35   경기   수원시  363422
# 36   경기   수원시  273835
# 37   경기   수원시  182321
# 38   경기   시흥시  505355
# 39   경기   안산시  317509
# 40   경기   안산시  362864
# 41   경기   안성시  186608
# 42   경기   안양시  310384
# 43   경기   안양시  242865
# 44   경기   양주시  233353
# 45   경기   양평군   99585
# 46   경기   여주시   97120
# 47   경기   연천군   42076
# 48   경기   오산시  229929
# 49   경기   용인시  445924
# 50   경기   용인시  378383
# 51   경기   용인시  269044
# 52   경기   의왕시  163356
# 53   경기  의정부시  460416
# 54   경기   이천시  218852
# 55   경기   파주시  489268
# 56   경기   평택시  564288
# 57   경기   포천시  138751
# ...

# %%
# df[df['sido']==lst[2]]['ssg']
new=[]
ap=list(df[df['sido']==lst[2]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
    # print(a[:3])
  else:
    new.append(a)
new
# Out:
# ['거제시',
#  '거창군',
#  '고성군',
#  '김해시',
#  '남해군',
#  '밀양시',
#  '사천시',
#  '산청군',
#  '양산시',
#  '의령군',
#  '진주시',
#  '창녕군',
#  '창원시',
#  '창원시',
#  '창원시',
#  '창원시',
#  '창원시',
#  '통영시',
#  '하동군',
#  '함안군',
#  '함양군',
#  '합천군']

# %%
df.loc[df['sido']==lst[2],'ssg']=new

# %%
new=[]
ap=list(df[df['sido']==lst[3]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
  else:
    new.append(a)
new
# Out:
# ['경산시',
#  '경주시',
#  '고령군',
#  '구미시',
#  '군위군',
#  '김천시',
#  '문경시',
#  '봉화군',
#  '상주시',
#  '성주군',
#  '안동시',
#  '영덕군',
#  '영양군',
#  '영주시',
#  '영천시',
#  '예천군',
#  '울릉군',
#  '울진군',
#  '의성군',
#  '청도군',
#  '청송군',
#  '칠곡군',
#  '포항시',
#  '포항시']

# %%
df.loc[df['sido']==lst[3],'ssg']=new

# %%
new=[]
ap=list(df[df['sido']==lst[13]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
  else:
    new.append(a)
new
# Out:
# ['고창군',
#  '군산시',
#  '김제시',
#  '남원시',
#  '무주군',
#  '부안군',
#  '순창군',
#  '완주군',
#  '익산시',
#  '임실군',
#  '장수군',
#  '전주시',
#  '전주시',
#  '정읍시',
#  '진안군']

# %%
df.loc[df['sido']==lst[13],'ssg']=new

# %%
new=[]
ap=list(df[df['sido']==lst[15]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
  else:
    new.append(a)
new
# Out:
# ['계룡시',
#  '공주시',
#  '금산군',
#  '논산시',
#  '당진시',
#  '보령시',
#  '부여군',
#  '서산시',
#  '서천군',
#  '아산시',
#  '예산군',
#  '천안시',
#  '천안시',
#  '청양군',
#  '태안군',
#  '홍성군']

# %%
df.loc[df['sido']==lst[15],'ssg']=new

# %%
new=[]
ap=list(df[df['sido']==lst[16]]['ssg'])
for a in ap:
  if len(a)>4:
    new.append(a[:3])
  else:
    new.append(a)
new
# Out:
# ['괴산군',
#  '단양군',
#  '보은군',
#  '영동군',
#  '옥천군',
#  '음성군',
#  '제천시',
#  '증평군',
#  '진천군',
#  '청주시',
#  '청주시',
#  '청주시',
#  '청주시',
#  '충주시']

# %%
df.loc[df['sido']==lst[16],'ssg']=new

# %%
t=pd.DataFrame(df.groupby(['sido','ssg'])['people'].sum()).reset_index()
t
# Out:
#     sido  ssg  people
# 0     강원  강릉시  205582
# 1     강원  고성군   20759
# 2     강원  동해시   89803
# 3     강원  삼척시   56421
# 4     강원  속초시   83552
# ..   ...  ...     ...
# 224   충북  제천시  127317
# 225   충북  증평군   37227
# 226   충북  진천군   88209
# 227   충북  청주시  844539
# 228   충북  충주시  199435
#
# [229 rows x 3 columns]

# %%
t_sido=list(t['sido'].unique())
print(f'시도 개수: {len(t_sido)}')
t_sgg=dict()
for sd in t_sido:
  t_sgg[sd]=list(t[t['sido']==sd]['ssg'].unique())
for sd in pr_sido:
  print(f'{sd}: {len(t_sgg[sd])}')
# Out:
# 시도 개수: 17
# 강원: 18
# 경기: 31
# 경남: 18
# 경북: 23
# 광주: 5
# 대구: 8
# 대전: 5
# 부산: 16
# 서울: 25
# 세종: 1
# 울산: 5
# 인천: 10
# 전남: 22
# 전북: 14
# 제주: 2
# 충남: 15
# 충북: 11

# %%
t.rename(columns={'sido':'시도','ssg':'시군구','people':'급수인구'},inplace=True)
t
# Out:
#      시도  시군구    급수인구
# 0    강원  강릉시  205582
# 1    강원  고성군   20759
# 2    강원  동해시   89803
# 3    강원  삼척시   56421
# 4    강원  속초시   83552
# ..   ..  ...     ...
# 224  충북  제천시  127317
# 225  충북  증평군   37227
# 226  충북  진천군   88209
# 227  충북  청주시  844539
# 228  충북  충주시  199435
#
# [229 rows x 3 columns]

# %%
p=int(t[t['시도']=='세종']['급수인구'])

# %%
# outputs
outputs=pd.merge(outputs,t,on=['시도','시군구'],how='left')
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구
# 0    강원  강릉시   24444   831434.0  205582.0
# 1    강원  고성군    2360   240614.0   20759.0
# 2    강원  동해시    8837   163638.0   89803.0
# 3    강원  삼척시    5644   130471.0   56421.0
# 4    강원  속초시   12489   629486.0   83552.0
# ..   ..  ...     ...        ...       ...
# 224  충북  제천시   12327   536522.0  127317.0
# 225  충북  증평군    4282    93140.0   37227.0
# 226  충북  진천군    8751   921726.0   88209.0
# 227  충북  청주시  180299  3712558.0  844539.0
# 228  충북  충주시   19992   877692.0  199435.0
#
# [229 rows x 5 columns]

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       1
# dtype: int64

# %%
outputs.loc[outputs['급수인구'].isna(),'급수인구']=p
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# dtype: int64

# %% [markdown]
# ### 쓰레기

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/쓰레기_최종.csv')
df
# Out:
#      시도   시군구        배출량
# 0    서울    소계  2905572.9
# 1    서울   종로구    95355.2
# 2    서울    중구    95998.1
# 3    서울   용산구    87049.0
# 4    서울   성동구    89652.9
# ..   ..   ...        ...
# 241  경남   거창군    27451.9
# 242  경남   합천군    14930.9
# 243  제주    소계   427368.3
# 244  제주   제주시   323450.3
# 245  제주  서귀포시   103918.0
#
# [246 rows x 3 columns]

# %%
df_=df[df['시군구']!='소계']
df_
# Out:
#      시도   시군구       배출량
# 1    서울   종로구   95355.2
# 2    서울    중구   95998.1
# 3    서울   용산구   87049.0
# 4    서울   성동구   89652.9
# 5    서울   광진구   80103.2
# ..   ..   ...       ...
# 240  경남   함양군   16747.6
# 241  경남   거창군   27451.9
# 242  경남   합천군   14930.9
# 244  제주   제주시  323450.3
# 245  제주  서귀포시  103918.0
#
# [229 rows x 3 columns]

# %%
t_sido=list(df_['시도'].unique())
print(f'시도 개수: {len(t_sido)}')
t_sgg=dict()
for sd in t_sido:
  t_sgg[sd]=list(df_[df_['시도']==sd]['시군구'].unique())
for sd in pr_sido:
  print(f'{sd}: {len(t_sgg[sd])}')
# Out:
# 시도 개수: 17
# 강원: 18
# 경기: 31
# 경남: 18
# 경북: 23
# 광주: 5
# 대구: 8
# 대전: 5
# 부산: 16
# 서울: 25
# 세종: 1
# 울산: 5
# 인천: 10
# 전남: 22
# 전북: 14
# 제주: 2
# 충남: 15
# 충북: 11

# %%
df2=df_.sort_values(['시도','시군구']).reset_index(drop=True)

# %%
p=float(df2[df2['시도']=='세종']['배출량'])

# %%
df2
# Out:
#      시도  시군구       배출량
# 0    강원  강릉시   73537.8
# 1    강원  고성군   17424.0
# 2    강원  동해시   41568.9
# 3    강원  삼척시   34251.5
# 4    강원  속초시   52093.9
# ..   ..  ...       ...
# 224  충북  제천시   50885.7
# 225  충북  증평군   12431.3
# 226  충북  진천군   35867.0
# 227  충북  청주시  309163.1
# 228  충북  충주시   79299.6
#
# [229 rows x 3 columns]

# %%
outputs=pd.merge(outputs,df2,on=['시도','시군구'],how='left')
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        1
# dtype: int64

# %%
outputs.loc[outputs['배출량'].isna(),'배출량']=p

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        0
# dtype: int64

# %%
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구       배출량
# 0    강원  강릉시   24444   831434.0  205582.0   73537.8
# 1    강원  고성군    2360   240614.0   20759.0   17424.0
# 2    강원  동해시    8837   163638.0   89803.0   41568.9
# 3    강원  삼척시    5644   130471.0   56421.0   34251.5
# 4    강원  속초시   12489   629486.0   83552.0   52093.9
# ..   ..  ...     ...        ...       ...       ...
# 224  충북  제천시   12327   536522.0  127317.0   50885.7
# 225  충북  증평군    4282    93140.0   37227.0   12431.3
# 226  충북  진천군    8751   921726.0   88209.0   35867.0
# 227  충북  청주시  180299  3712558.0  844539.0  309163.1
# 228  충북  충주시   19992   877692.0  199435.0   79299.6
#
# [229 rows x 6 columns]

# %% [markdown]
# ### 사회복지

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/장기요양_최종.csv')
df
# Out:
#      시도   시군구     정원
# 0    서울    소계  32385
# 1    서울   종로구    458
# 2    서울    중구    286
# 3    서울   용산구    370
# 4    서울   성동구    886
# ..   ..   ...    ...
# 261  경남   거창군    934
# 262  경남   합천군    780
# 263  제주    소계   5770
# 264  제주   제주시   4001
# 265  제주  서귀포시   1769
#
# [266 rows x 3 columns]

# %%
df_=df[df['시군구']!='소계']
df_
# Out:
#      시도   시군구    정원
# 1    서울   종로구   458
# 2    서울    중구   286
# 3    서울   용산구   370
# 4    서울   성동구   886
# 5    서울   광진구  1258
# ..   ..   ...   ...
# 260  경남   함양군   832
# 261  경남   거창군   934
# 262  경남   합천군   780
# 264  제주   제주시  4001
# 265  제주  서귀포시  1769
#
# [249 rows x 3 columns]

# %%
lst=list(df_['시도'].unique())
# df_[df_['시도']==lst[0]]

# %%
sgg_lst=list(df_[df_['시도']==lst[7]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
# new

# %%
df_.loc[df['시도']==lst[7],'시군구']=new

# %%
sgg_lst=list(df_[df_['시도']==lst[9]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
new
# Out:
# ['청주시',
#  '청주시',
#  '청주시',
#  '청주시',
#  '충주시',
#  '제천시',
#  '보은군',
#  '옥천군',
#  '영동군',
#  '증평군',
#  '진천군',
#  '괴산군',
#  '음성군',
#  '단양군']

# %%
df_.loc[df['시도']==lst[9],'시군구']=new

# %%
sgg_lst=list(df_[df_['시도']==lst[10]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
new
# Out:
# ['천안시',
#  '천안시',
#  '공주시',
#  '보령시',
#  '아산시',
#  '서산시',
#  '논산시',
#  '계룡시',
#  '당진시',
#  '금산군',
#  '부여군',
#  '서천군',
#  '청양군',
#  '홍성군',
#  '예산군',
#  '태안군']

# %%
df_.loc[df['시도']==lst[10],'시군구']=new

# %%
sgg_lst=list(df_[df_['시도']==lst[11]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
df_.loc[df['시도']==lst[11],'시군구']=new

# %%
sgg_lst=list(df_[df_['시도']==lst[13]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
df_.loc[df['시도']==lst[13],'시군구']=new

# %%
sgg_lst=list(df_[df_['시도']==lst[14]]['시군구'])
new=[]
for l in sgg_lst:
  if len(l)>4:
    new.append(l[:3])
  else:
    new.append(l)
df_.loc[df['시도']==lst[14],'시군구']=new

# %%
df2=df_.reset_index(drop=True)
men=round(df2['정원'].mean(),3)
df2.loc[249]=['세종','세종시',men]
df2
# Out:
#      시도   시군구        정원
# 0    서울   종로구   458.000
# 1    서울    중구   286.000
# 2    서울   용산구   370.000
# 3    서울   성동구   886.000
# 4    서울   광진구  1258.000
# ..   ..   ...       ...
# 245  경남   거창군   934.000
# 246  경남   합천군   780.000
# 247  제주   제주시  4001.000
# 248  제주  서귀포시  1769.000
# 249  세종   세종시  1653.373
#
# [250 rows x 3 columns]

# %%
final=pd.DataFrame(df2.groupby(['시도','시군구']).sum()).reset_index()
final
# Out:
#      시도  시군구       정원
# 0    강원  강릉시   3056.0
# 1    강원  고성군    317.0
# 2    강원  동해시    738.0
# 3    강원  삼척시    608.0
# 4    강원  속초시    814.0
# ..   ..  ...      ...
# 224  충북  제천시   1436.0
# 225  충북  증평군    493.0
# 226  충북  진천군   1115.0
# 227  충북  청주시  10343.0
# 228  충북  충주시   2531.0
#
# [229 rows x 3 columns]

# %%
# final.rename(columns={'정원'})
# Out:
#      시도  시군구       정원
# 0    강원  강릉시   3056.0
# 1    강원  고성군    317.0
# 2    강원  동해시    738.0
# 3    강원  삼척시    608.0
# 4    강원  속초시    814.0
# ..   ..  ...      ...
# 224  충북  제천시   1436.0
# 225  충북  증평군    493.0
# 226  충북  진천군   1115.0
# 227  충북  청주시  10343.0
# 228  충북  충주시   2531.0
#
# [229 rows x 3 columns]

# %%
outputs=pd.merge(outputs,final,on=['시도','시군구'],how='left')
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        0
# 정원         1
# dtype: int64

# %%
outputs.rename(columns={'정원':'복지시설 정원'},inplace=True)
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구       배출량  복지시설 정원
# 0    강원  강릉시   24444   831434.0  205582.0   73537.8   3056.0
# 1    강원  고성군    2360   240614.0   20759.0   17424.0    317.0
# 2    강원  동해시    8837   163638.0   89803.0   41568.9    738.0
# 3    강원  삼척시    5644   130471.0   56421.0   34251.5    608.0
# 4    강원  속초시   12489   629486.0   83552.0   52093.9    814.0
# ..   ..  ...     ...        ...       ...       ...      ...
# 224  충북  제천시   12327   536522.0  127317.0   50885.7   1436.0
# 225  충북  증평군    4282    93140.0   37227.0   12431.3    493.0
# 226  충북  진천군    8751   921726.0   88209.0   35867.0   1115.0
# 227  충북  청주시  180299  3712558.0  844539.0  309163.1  10343.0
# 228  충북  충주시   19992   877692.0  199435.0   79299.6   2531.0
#
# [229 rows x 7 columns]

# %%
p=float(final[final['시도']=='세종']['정원'])
outputs.loc[outputs['복지시설 정원'].isna(),'복지시설 정원']=p
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구       배출량  복지시설 정원
# 0    강원  강릉시   24444   831434.0  205582.0   73537.8   3056.0
# 1    강원  고성군    2360   240614.0   20759.0   17424.0    317.0
# 2    강원  동해시    8837   163638.0   89803.0   41568.9    738.0
# 3    강원  삼척시    5644   130471.0   56421.0   34251.5    608.0
# 4    강원  속초시   12489   629486.0   83552.0   52093.9    814.0
# ..   ..  ...     ...        ...       ...       ...      ...
# 224  충북  제천시   12327   536522.0  127317.0   50885.7   1436.0
# 225  충북  증평군    4282    93140.0   37227.0   12431.3    493.0
# 226  충북  진천군    8751   921726.0   88209.0   35867.0   1115.0
# 227  충북  청주시  180299  3712558.0  844539.0  309163.1  10343.0
# 228  충북  충주시   19992   877692.0  199435.0   79299.6   2531.0
#
# [229 rows x 7 columns]

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        0
# 복지시설 정원    0
# dtype: int64

# %% [markdown]
# ### 문화

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/문화_최종.csv')
df
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 250  충북  제천시  16
# 251  충북  증평군   6
# 252  충북  진천군   9
# 253  충북  청주시  47
# 254  충북  충주시  19
#
# [255 rows x 3 columns]

# %%
df['시도']=df['시도'].apply(lambda x:x.replace(' ',''))
df
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 250  충북  제천시  16
# 251  충북  증평군   6
# 252  충북  진천군   9
# 253  충북  청주시  47
# 254  충북  충주시  19
#
# [255 rows x 3 columns]

# %%
lst=list(df['시도'].unique())

# %%
t_sido=list(df['시도'].unique())
print(f'시도 개수: {len(t_sido)}')
t_sgg=dict()
for sd in t_sido:
  t_sgg[sd]=list(df[df['시도']==sd]['시군구'].unique())
for sd in pr_sido:
  print(f'{sd}: {len(t_sgg[sd])}')
# 경기: 31
# 대구: 8
# 대전: 5
# 서울: 25
# 세종: 1
# 전북: 14
# 제주: 2
# Out:
# 시도 개수: 17
# 강원: 18
# 경기: 33
# 경남: 18
# 경북: 23
# 광주: 5
# 대구: 9
# 대전: 7
# 부산: 16
# 서울: 26
# 세종: 4
# 울산: 5
# 인천: 10
# 전남: 22
# 전북: 15
# 제주: 4
# 충남: 15
# 충북: 11

# %%
# df[df['시도']=='경기']
df['시군구']=df['시군구'].apply(lambda x:x.strip())

# %%
t_sido=list(df['시도'].unique())
print(f'시도 개수: {len(t_sido)}')
t_sgg=dict()
for sd in t_sido:
  t_sgg[sd]=list(df[df['시도']==sd]['시군구'].unique())
for sd in pr_sido:
  print(f'{sd}: {len(t_sgg[sd])}')
# 경기: 31 V
# 대구: 8 V
# 대전: 5 V
# 서울: 25 V
# 세종: 1 V
# Out:
# 시도 개수: 17
# 강원: 18
# 경기: 31
# 경남: 18
# 경북: 23
# 광주: 5
# 대구: 9
# 대전: 6
# 부산: 16
# 서울: 26
# 세종: 4
# 울산: 5
# 인천: 10
# 전남: 22
# 전북: 14
# 제주: 2
# 충남: 15
# 충북: 11

# %%
df2=df[df['시군구']!='본청'] # 대구 대전 제외
df2
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 250  충북  제천시  16
# 251  충북  증평군   6
# 252  충북  진천군   9
# 253  충북  청주시  47
# 254  충북  충주시  19
#
# [253 rows x 3 columns]

# %%
# df2[df2['시도']=='서울'] # 서울시 제외
df2=df2[df2['시군구']!='서울시']
df2
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 250  충북  제천시  16
# 251  충북  증평군   6
# 252  충북  진천군   9
# 253  충북  청주시  47
# 254  충북  충주시  19
#
# [252 rows x 3 columns]

# %%
df2.loc[df2['시도']=='세종','시군구']='세종시'

# %%
df3=pd.DataFrame(df2.groupby(['시도','시군구'])['개수'].sum()).reset_index()
df3
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 224  충북  제천시  16
# 225  충북  증평군   6
# 226  충북  진천군   9
# 227  충북  청주시  47
# 228  충북  충주시  19
#
# [229 rows x 3 columns]

# %%
final=df3.sort_values(['시도','시군구'])

# %%
final
# Out:
#      시도  시군구  개수
# 0    강원  강릉시  31
# 1    강원  고성군  15
# 2    강원  동해시   7
# 3    강원  삼척시   9
# 4    강원  속초시   9
# ..   ..  ...  ..
# 224  충북  제천시  16
# 225  충북  증평군   6
# 226  충북  진천군   9
# 227  충북  청주시  47
# 228  충북  충주시  19
#
# [229 rows x 3 columns]

# %%
final.rename(columns={'개수':'문화시설 개수'},inplace=True)
final
# Out:
#      시도  시군구  문화시설 개수
# 0    강원  강릉시       31
# 1    강원  고성군       15
# 2    강원  동해시        7
# 3    강원  삼척시        9
# 4    강원  속초시        9
# ..   ..  ...      ...
# 224  충북  제천시       16
# 225  충북  증평군        6
# 226  충북  진천군        9
# 227  충북  청주시       47
# 228  충북  충주시       19
#
# [229 rows x 3 columns]

# %%
outputs=pd.merge(outputs,final,on=['시도','시군구'],how='left')
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구       배출량  복지시설 정원  문화시설 개수
# 0    강원  강릉시   24444   831434.0  205582.0   73537.8   3056.0     31.0
# 1    강원  고성군    2360   240614.0   20759.0   17424.0    317.0     15.0
# 2    강원  동해시    8837   163638.0   89803.0   41568.9    738.0      7.0
# 3    강원  삼척시    5644   130471.0   56421.0   34251.5    608.0      9.0
# 4    강원  속초시   12489   629486.0   83552.0   52093.9    814.0      9.0
# ..   ..  ...     ...        ...       ...       ...      ...      ...
# 224  충북  제천시   12327   536522.0  127317.0   50885.7   1436.0     16.0
# 225  충북  증평군    4282    93140.0   37227.0   12431.3    493.0      6.0
# 226  충북  진천군    8751   921726.0   88209.0   35867.0   1115.0      9.0
# 227  충북  청주시  180299  3712558.0  844539.0  309163.1  10343.0     47.0
# 228  충북  충주시   19992   877692.0  199435.0   79299.6   2531.0     19.0
#
# [229 rows x 8 columns]

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        0
# 복지시설 정원    0
# 문화시설 개수    1
# dtype: int64

# %%
outputs[outputs['문화시설 개수'].isna()]
# Out:
#      시도 시군구   민원건수    건축허가 면적      급수인구       배출량   복지시설 정원  문화시설 개수
# 149  세종  세종  27753  1247607.0  371580.0  101623.3  1653.373      NaN

# %%
p=int(final[final['시도']=='세종']['문화시설 개수'])
outputs.loc[outputs['문화시설 개수'].isna(),'문화시설 개수']=p

# %%
outputs
# Out:
#      시도  시군구    민원건수    건축허가 면적      급수인구       배출량  복지시설 정원  문화시설 개수
# 0    강원  강릉시   24444   831434.0  205582.0   73537.8   3056.0     31.0
# 1    강원  고성군    2360   240614.0   20759.0   17424.0    317.0     15.0
# 2    강원  동해시    8837   163638.0   89803.0   41568.9    738.0      7.0
# 3    강원  삼척시    5644   130471.0   56421.0   34251.5    608.0      9.0
# 4    강원  속초시   12489   629486.0   83552.0   52093.9    814.0      9.0
# ..   ..  ...     ...        ...       ...       ...      ...      ...
# 224  충북  제천시   12327   536522.0  127317.0   50885.7   1436.0     16.0
# 225  충북  증평군    4282    93140.0   37227.0   12431.3    493.0      6.0
# 226  충북  진천군    8751   921726.0   88209.0   35867.0   1115.0      9.0
# 227  충북  청주시  180299  3712558.0  844539.0  309163.1  10343.0     47.0
# 228  충북  충주시   19992   877692.0  199435.0   79299.6   2531.0     19.0
#
# [229 rows x 8 columns]

# %%
outputs.isna().sum()
# Out:
# 시도         0
# 시군구        0
# 민원건수       0
# 건축허가 면적    0
# 급수인구       0
# 배출량        0
# 복지시설 정원    0
# 문화시설 개수    0
# dtype: int64

# %%
inputs
# Out:
#      시도  시군구   주민1인당 세출예산액   천명당 공무원수
# 0    강원  강릉시   5594.350790   6.954194
# 1    강원  고성군  14064.505340  20.074131
# 2    강원  동해시   4992.227307   7.826290
# 3    강원  삼척시   9015.543442  13.968374
# 4    강원  속초시   4949.341341   8.503340
# ..   ..  ...           ...        ...
# 224  충북  제천시   6769.078075   9.453534
# 225  충북  증평군   6671.725636  12.902872
# 226  충북  진천군   6276.415692   9.603644
# 227  충북  청주시   3042.843402   3.879870
# 228  충북  충주시   5021.350944   7.083560
#
# [229 rows x 4 columns]

# %%
inputs.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/dea_inputs.csv',index=False)

# %%
outputs.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/dea_outputs.csv',index=False)
