# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/장기요양.csv')
df
# Out:
#      시·군·구별(1)  시·군·구별(2)     2022  2022.1   2022.2  2022.3   2022.4   2022.5  \
# 0    시·군·구별(1)  시·군·구별(2)        계       계       재가      재가       재가       재가
# 1    시·군·구별(1)  시·군·구별(2)       소계      소계       소계      소계     방문요양     방문목욕
# 2    시·군·구별(1)  시·군·구별(2)  기관수 (개)  정원 (명)  기관수 (개)  정원 (명)  기관수 (개)  기관수 (개)
# 3           합계         소계    27484  413432    21334  178988    16850    11789
# 4           서울         소계     3646   32385     3144   16260     2460     1989
# ..         ...        ...      ...     ...      ...     ...      ...      ...
# 265         경남        거창군       46     934       38     539       25       21
# 266         경남        합천군       37     780       31     263       23       13
# 267         제주         소계      241    5770      171    1797      110       84
# 268         제주        제주시      182    4001      133    1218       86       65
# 269         제주       서귀포시       59    1769       38     579       24       19
#
# ...

# %%
final=df.iloc[4:,0:2].reset_index(drop=True)
final['정원']=df.iloc[4:,3].reset_index(drop=True)
final
# Out:
#     시·군·구별(1) 시·군·구별(2)     정원
# 0          서울        소계  32385
# 1          서울       종로구    458
# 2          서울        중구    286
# 3          서울       용산구    370
# 4          서울       성동구    886
# ..        ...       ...    ...
# 261        경남       거창군    934
# 262        경남       합천군    780
# 263        제주        소계   5770
# 264        제주       제주시   4001
# 265        제주      서귀포시   1769
#
# [266 rows x 3 columns]

# %%
final.rename(columns={'시·군·구별(1)':'시도','시·군·구별(2)':'시군구'},inplace=True)
final
# Out:
#      시도   시군구     정원
# 0    서울    소계  32385
# 1    서울   종로구    458
# 2    서울    중구    286
# 3    서울   용산구    370
# 4    서울   성동구    886
# ..   ..   ...    ...
# 261  경남   거창군    934
# 262  경남   합천군    780
# 263  제주    소계   5770
# 264  제주   제주시   4001
# 265  제주  서귀포시   1769
#
# [266 rows x 3 columns]

# %%
final.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/전처리/장기요양_최종.csv',index=False)
