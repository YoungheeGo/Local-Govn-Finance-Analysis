# %%
import pandas as pd

# %%
df4=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 04월 시군구별_용도별 건축허가현황.xlsx')
df4
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     2022년 04월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                       구분          NaN    전체용도 합계       단독주택
# 1                                      NaN          NaN        NaN       단독주택
# 2                                   전국(전체)          NaN   17903079     585357
# 3                                서울특별시(전체)          NaN    1371479       8545
# 4                                    서울특별시        서울특별시     101239          0
# ..                                     ...          ...        ...        ...
# 292                                   경상남도       창원시진해구       9235        993
# 293                            제주특별자치도(전체)          NaN     280148      36235
# ...

# %%
df4_=df4.iloc[3:,:3].reset_index(drop=True)
df4_.rename(columns={'2022년 04월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적(m^2)'},inplace=True)
df4_
# Out:
#               시도          시군구  면적(m^2)
# 0      서울특별시(전체)          NaN  1371479
# 1          서울특별시        서울특별시   101239
# 2          서울특별시       서울시강남구    81984
# 3          서울특별시       서울시강동구    13289
# 4          서울특별시       서울시강북구     9600
# ..           ...          ...      ...
# 289         경상남도       창원시진해구     9235
# 290  제주특별자치도(전체)          NaN   280148
# 291      제주특별자치도      제주특별자치도        0
# 292      제주특별자치도  제주특별자치도서귀포시   164646
# 293      제주특별자치도   제주특별자치도제주시   115502
#
# [294 rows x 3 columns]

# %%
df4__=df4_[~ df4_['시군구'].isna()].reset_index(drop=True)
df4__
# Out:
#           시도          시군구 면적(m^2)
# 0      서울특별시        서울특별시  101239
# 1      서울특별시       서울시강남구   81984
# 2      서울특별시       서울시강동구   13289
# 3      서울특별시       서울시강북구    9600
# 4      서울특별시       서울시강서구  330573
# ..       ...          ...     ...
# 272     경상남도       창원시의창구    7856
# 273     경상남도       창원시진해구    9235
# 274  제주특별자치도      제주특별자치도       0
# 275  제주특별자치도  제주특별자치도서귀포시  164646
# 276  제주특별자치도   제주특별자치도제주시  115502
#
# [277 rows x 3 columns]

# %%
df=pd.read_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/건축.csv',encoding='cp949')
df
# Out:
#           시도          시군구       1월     2월      3월  4월
# 0      서울특별시        서울특별시  164,395  86938   28375 NaN
# 1      서울특별시       서울시강남구   94,364  96756  100546 NaN
# 2      서울특별시       서울시강동구   20,238  60364   41706 NaN
# 3      서울특별시       서울시강북구    5,353   4791   13006 NaN
# 4      서울특별시       서울시강서구   64,010  44677   26426 NaN
# ..       ...          ...      ...    ...     ...  ..
# 272     경상남도       창원시의창구    10624  21771   12850 NaN
# 273     경상남도       창원시진해구     5324  20310    6435 NaN
# 274  제주특별자치도      제주특별자치도      353      0       0 NaN
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728 NaN
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464 NaN
#
# [277 rows x 6 columns]

# %%
df['4월']=df4__['면적(m^2)']
df
# Out:
#           시도          시군구       1월     2월      3월      4월
# 0      서울특별시        서울특별시  164,395  86938   28375  101239
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573
# ..       ...          ...      ...    ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856
# 273     경상남도       창원시진해구     5324  20310    6435    9235
# 274  제주특별자치도      제주특별자치도      353      0       0       0
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502
#
# [277 rows x 6 columns]

# %%
df5=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 05월 시군구별_용도별 건축허가현황.xlsx')
df5
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     2022년 05월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                       구분          NaN    전체용도 합계       단독주택
# 1                                      NaN          NaN        NaN       단독주택
# 2                                   전국(전체)          NaN   19521870     568403
# 3                                서울특별시(전체)          NaN     836130       6084
# 4                                    서울특별시        서울특별시          0          0
# ..                                     ...          ...        ...        ...
# 292                                   경상남도       창원시진해구       7414        467
# 293                            제주특별자치도(전체)          NaN     383003      27013
# ...

# %%
df5_=df5.iloc[3:,:3].reset_index(drop=True)
df5_.rename(columns={'2022년 05월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적(m^2)'},inplace=True)
df5__=df5_[~ df5_['시군구'].isna()].reset_index(drop=True)
df5__
# Out:
#           시도          시군구 면적(m^2)
# 0      서울특별시        서울특별시       0
# 1      서울특별시       서울시강남구   81538
# 2      서울특별시       서울시강동구   22335
# 3      서울특별시       서울시강북구   28348
# 4      서울특별시       서울시강서구   35161
# ..       ...          ...     ...
# 272     경상남도       창원시의창구    5969
# 273     경상남도       창원시진해구    7414
# 274  제주특별자치도      제주특별자치도     130
# 275  제주특별자치도  제주특별자치도서귀포시   55234
# 276  제주특별자치도   제주특별자치도제주시  327639
#
# [277 rows x 3 columns]

# %%
df['5월']=df5__['면적(m^2)']
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161
# ..       ...          ...      ...    ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639
#
# [277 rows x 7 columns]

# %%
df6=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 06월 시군구별_용도별 건축허가현황.xlsx')
df6
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     2022년 06월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                       구분          NaN    전체용도 합계       단독주택
# 1                                      NaN          NaN        NaN       단독주택
# 2                                   전국(전체)          NaN   14964001     488050
# 3                                서울특별시(전체)          NaN    1241191       8623
# 4                                    서울특별시        서울특별시     156744          0
# ..                                     ...          ...        ...        ...
# 292                                   경상남도       창원시진해구       9675        263
# 293                            제주특별자치도(전체)          NaN     247213      32918
# ...

# %%
df6_=df6.iloc[3:,:3].reset_index(drop=True)
df6_.rename(columns={'2022년 06월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df6__=df6_[~ df6_['시군구'].isna()].reset_index(drop=True)
df6__
# Out:
#           시도          시군구      면적
# 0      서울특별시        서울특별시  156744
# 1      서울특별시       서울시강남구   66746
# 2      서울특별시       서울시강동구   78202
# 3      서울특별시       서울시강북구    8360
# 4      서울특별시       서울시강서구   58297
# ..       ...          ...     ...
# 272     경상남도       창원시의창구    9589
# 273     경상남도       창원시진해구    9675
# 274  제주특별자치도      제주특별자치도      90
# 275  제주특별자치도  제주특별자치도서귀포시  104234
# 276  제주특별자치도   제주특별자치도제주시  142889
#
# [277 rows x 3 columns]

# %%
df['6월']=df6__['면적']

# %%
df7=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 07월 시군구별_용도별 건축허가현황.xlsx')
df7
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     2022년 07월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]   Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                       구분          NaN    전체용도 합계       단독주택
# 1                                      NaN          NaN        NaN       단독주택
# 2                                   전국(전체)          NaN   15615767     449843
# 3                                서울특별시(전체)          NaN    1312542      13335
# 4                                    서울특별시        서울특별시      14892          0
# ..                                     ...          ...        ...        ...
# 292                                   경상남도       창원시진해구       8292        658
# 293                            제주특별자치도(전체)          NaN     334045      33002
# ...

# %%
df7_=df7.iloc[3:,:3].reset_index(drop=True)
df7_.rename(columns={'2022년 07월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df7__=df7_[~ df7_['시군구'].isna()].reset_index(drop=True)
df7__
# Out:
#           시도          시군구      면적
# 0      서울특별시        서울특별시   14892
# 1      서울특별시       서울시강남구   79006
# 2      서울특별시       서울시강동구    8362
# 3      서울특별시       서울시강북구   16717
# 4      서울특별시       서울시강서구   72048
# ..       ...          ...     ...
# 272     경상남도       창원시의창구   11687
# 273     경상남도       창원시진해구    8292
# 274  제주특별자치도      제주특별자치도       0
# 275  제주특별자치도  제주특별자치도서귀포시   53159
# 276  제주특별자치도   제주특별자치도제주시  280886
#
# [277 rows x 3 columns]

# %%
df['7월']=df7__['면적']
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161   58297
# ..       ...          ...      ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639  142889
#
#          7월
# 0     14892
# 1     79006
# 2      8362
# 3     16717
# ...

# %%
df8=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 08월 시군구별_용도별 건축허가현황.xlsx')
df8_=df8.iloc[3:,:3].reset_index(drop=True)
df8_.rename(columns={'2022년 08월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df8__=df8_[~ df8_['시군구'].isna()].reset_index(drop=True)
df8__
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           시도          시군구      면적
# 0      서울특별시        서울특별시   68578
# 1      서울특별시       서울시강남구  160353
# 2      서울특별시       서울시강동구   34962
# 3      서울특별시       서울시강북구    5030
# 4      서울특별시       서울시강서구  218138
# ..       ...          ...     ...
# 272     경상남도       창원시의창구   10603
# 273     경상남도       창원시진해구    3513
# 274  제주특별자치도      제주특별자치도    1248
# 275  제주특별자치도  제주특별자치도서귀포시   48691
# 276  제주특별자치도   제주특별자치도제주시  162928
#
# [277 rows x 3 columns]

# %%
df['8월']=df8__['면적']

# %%
df9=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 09월 시군구별_용도별 건축허가현황.xlsx')
df9_=df9.iloc[3:,:3].reset_index(drop=True)
df9_.rename(columns={'2022년 09월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df9__=df9_[~ df9_['시군구'].isna()].reset_index(drop=True)
df9__
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           시도          시군구      면적
# 0      서울특별시        서울특별시   10264
# 1      서울특별시       서울시강남구  270001
# 2      서울특별시       서울시강동구   18378
# 3      서울특별시       서울시강북구    5285
# 4      서울특별시       서울시강서구  116378
# ..       ...          ...     ...
# 272     경상남도       창원시의창구   16485
# 273     경상남도       창원시진해구    2592
# 274  제주특별자치도      제주특별자치도       0
# 275  제주특별자치도  제주특별자치도서귀포시   45522
# 276  제주특별자치도   제주특별자치도제주시  182865
#
# [277 rows x 3 columns]

# %%
df['9월']=df9__['면적']
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161   58297
# ..       ...          ...      ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639  142889
#
#          7월      8월      9월
# 0     14892   68578   10264
# ...

# %%
df10=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 10월 시군구별_용도별 건축허가현황.xlsx')
df10_=df10.iloc[3:,:3].reset_index(drop=True)
df10_.rename(columns={'2022년 10월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df10__=df10_[~ df10_['시군구'].isna()].reset_index(drop=True)
df10__
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           시도          시군구      면적
# 0      서울특별시        서울특별시       0
# 1      서울특별시       서울시강남구   92327
# 2      서울특별시       서울시강동구   26949
# 3      서울특별시       서울시강북구   69441
# 4      서울특별시       서울시강서구   21600
# ..       ...          ...     ...
# 272     경상남도       창원시의창구    6394
# 273     경상남도       창원시진해구    6025
# 274  제주특별자치도      제주특별자치도       0
# 275  제주특별자치도  제주특별자치도서귀포시   29885
# 276  제주특별자치도   제주특별자치도제주시  121138
#
# [277 rows x 3 columns]

# %%
df['10월']=df10__['면적']
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161   58297
# ..       ...          ...      ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639  142889
#
#          7월      8월      9월     10월
# 0     14892   68578   10264       0
# ...

# %%
df11=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 11월 시군구별_용도별 건축허가현황.xlsx')
df11_=df11.iloc[3:,:3].reset_index(drop=True)
df11_.rename(columns={'2022년 11월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df11__=df11_[~ df11_['시군구'].isna()].reset_index(drop=True)
df11__
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           시도          시군구      면적
# 0      서울특별시        서울특별시   42257
# 1      서울특별시       서울시강남구  104116
# 2      서울특별시       서울시강동구   27492
# 3      서울특별시       서울시강북구    4494
# 4      서울특별시       서울시강서구   52934
# ..       ...          ...     ...
# 272     경상남도       창원시의창구    8309
# 273     경상남도       창원시진해구    3866
# 274  제주특별자치도      제주특별자치도    1180
# 275  제주특별자치도  제주특별자치도서귀포시   38052
# 276  제주특별자치도   제주특별자치도제주시  146702
#
# [277 rows x 3 columns]

# %%
df['11월']=df11__['면적']
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161   58297
# ..       ...          ...      ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639  142889
#
#          7월      8월      9월     10월     11월
# ...

# %%
df12=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 12월 시군구별_용도별 건축허가현황.xlsx')
df12_=df12.iloc[3:,:3].reset_index(drop=True)
df12_.rename(columns={'2022년 12월 시군구별/용도별 건축허가현황 [단위 : 면적(㎡)]':'시도',
                     'Unnamed: 1':'시군구','Unnamed: 2':'면적'},inplace=True)
df12__=df12_[~ df12_['시군구'].isna()].reset_index(drop=True)
df12__
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           시도          시군구      면적
# 0      서울특별시        서울특별시   52967
# 1      서울특별시       서울시강남구  273254
# 2      서울특별시       서울시강동구   29158
# 3      서울특별시       서울시강북구    6004
# 4      서울특별시       서울시강서구  111051
# ..       ...          ...     ...
# 272     경상남도       창원시의창구   11502
# 273     경상남도       창원시진해구   19312
# 274  제주특별자치도      제주특별자치도       0
# 275  제주특별자치도  제주특별자치도서귀포시   51287
# 276  제주특별자치도   제주특별자치도제주시  105779
#
# [277 rows x 3 columns]

# %%
df['12월']=df12__['면적']

# %%
df
# Out:
#           시도          시군구       1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164,395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94,364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20,238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5,353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64,010  44677   26426  330573   35161   58297
# ..       ...          ...      ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구    10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구     5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도      353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시    66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시    97447  94310   95464  115502  327639  142889
#
#          7월      8월      9월     10월     11월     12월
# ...

# %%
df.dtypes
# Out:
# 시도     object
# 시군구    object
# 1월     object
# 2월      int64
# 3월      int64
# 4월     object
# 5월     object
# 6월     object
# 7월     object
# 8월     object
# 9월     object
# 10월    object
# 11월    object
# 12월    object
# dtype: object

# %%
df['1월']=df['1월'].apply(lambda x:x.replace(',','')).astype('int')

# %%
df['4월']=df['4월'].astype('int')
df['5월']=df['5월'].astype('int')
df['6월']=df['6월'].astype('int')
df['7월']=df['7월'].astype('int')
df['8월']=df['8월'].astype('int')
df['9월']=df['9월'].astype('int')
df['10월']=df['10월'].astype('int')
df['11월']=df['11월'].astype('int')
df['12월']=df['12월'].astype('int')

# %%
df.dtypes
# Out:
# 시도     object
# 시군구    object
# 1월      int64
# 2월      int64
# 3월      int64
# 4월      int64
# 5월      int64
# 6월      int64
# 7월      int64
# 8월      int64
# 9월      int64
# 10월     int64
# 11월     int64
# 12월     int64
# dtype: object

# %%
df['total']=df['1월']+df['2월']+df['3월']+df['4월']+df['5월']+df['6월']+df['7월']+df['8월']+df['9월']+df['10월']+df['11월']+df['12월']
df
# Out:
#           시도          시군구      1월     2월      3월      4월      5월      6월  \
# 0      서울특별시        서울특별시  164395  86938   28375  101239       0  156744
# 1      서울특별시       서울시강남구   94364  96756  100546   81984   81538   66746
# 2      서울특별시       서울시강동구   20238  60364   41706   13289   22335   78202
# 3      서울특별시       서울시강북구    5353   4791   13006    9600   28348    8360
# 4      서울특별시       서울시강서구   64010  44677   26426  330573   35161   58297
# ..       ...          ...     ...    ...     ...     ...     ...     ...
# 272     경상남도       창원시의창구   10624  21771   12850    7856    5969    9589
# 273     경상남도       창원시진해구    5324  20310    6435    9235    7414    9675
# 274  제주특별자치도      제주특별자치도     353      0       0       0     130      90
# 275  제주특별자치도  제주특별자치도서귀포시   66559  38190   68728  164646   55234  104234
# 276  제주특별자치도   제주특별자치도제주시   97447  94310   95464  115502  327639  142889
#
#          7월      8월      9월     10월     11월     12월    total
# ...

# %%
final=df[['시도','시군구','total']]
final
# Out:
#           시도          시군구    total
# 0      서울특별시        서울특별시   726649
# 1      서울특별시       서울시강남구  1500991
# 2      서울특별시       서울시강동구   381435
# 3      서울특별시       서울시강북구   176429
# 4      서울특별시       서울시강서구  1151293
# ..       ...          ...      ...
# 272     경상남도       창원시의창구   133639
# 273     경상남도       창원시진해구   101993
# 274  제주특별자치도      제주특별자치도     3001
# 275  제주특별자치도  제주특별자치도서귀포시   764187
# 276  제주특별자치도   제주특별자치도제주시  1873549
#
# [277 rows x 3 columns]

# %%
#df12=pd.read_excel('/content/drive/MyDrive/한국정책 공모전/예산효율성data/2022년 12월 시군구별_용도별 건축허가현황.xlsx')
final.to_csv('/content/drive/MyDrive/한국정책 공모전/예산효율성data/건축_최종.csv',index=False)

# %%
import requests
key='T7qWS/9fhkbGnJOLvtsKjAAARGoy/4dtTP7RqVqRuL+cj5jbRt2nEWgA/s3wAsSYW29Kg59YOafhLoqC1KJWLg=='
url = 'http://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo'
params ={'serviceKey' : key, 'sigunguCd' : '11680', 'bjdongCd' : '10300', 'platGbCd' : '0', 'bun' : '0012', 'ji' : '0004', 'startDate' : '', 'endDate' : '', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
contents=response.content
print(contents)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><archArea>1152.45</archArea><archGbCd>0700</archGbCd><archGbCdNm>\xec\x9a\xa9\xeb\x8f\x84\xeb\xb3\x80\xea\xb2\xbd</archGbCdNm><archPmsDay>20000309</archPmsDay><atchBldDongCnt>0</atchBldDongCnt><bcRat>50.72</bcRat><bjdongCd>10300</bjdongCd><bldNm>12-4</bldNm><block> </block><bun>0012</bun><crtnDay>20090320</crtnDay><fmlyCnt>0</fmlyCnt><guyukCd> </guyukCd><guyukCdNm> </guyukCdNm><hhldCnt>0</hhldCnt><hoCnt>0</hoCnt><ji>0004</ji><jiguCd> </jiguCd><jiguCdNm> </jiguCdNm><jimokCd>08</jimokCd><jimokCdNm>\xeb\x8c\x80</jimokCdNm><jiyukCd>1020</jiyukCd><jiyukCdNm>\xec\x9d\xbc\xeb\xb0\x98\xec\xa3\xbc\xea\xb1\xb0\xec\xa7\x80\xec\x97\xad</jiyukCdNm><lot> </lot><mainBldCnt>1</mainBldCnt><mainPurpsCd>Z5000</mainPurpsCd><mainPurpsCdNm>\xeb\xac\xb8\xed\x99\x94\xeb\xb0\x8f\xec\xa7\x91\xed\x9a\x8c\xec\x8b\x9c\xec\x84\xa4</mainPurpsCdNm><m
# ...

# %%
# !pip install xmltodict

# %%
import json
import xmltodict

# %%
jsonString = json.dumps(xmltodict.parse(contents), indent=4, ensure_ascii=False)
print(jsonString)
# Out:
# {
#     "response": {
#         "header": {
#             "resultCode": "00",
#             "resultMsg": "NORMAL SERVICE."
#         },
#         "body": {
#             "items": {
#                 "item": [
#                     {
#                         "archArea": "1152.45",
#                         "archGbCd": "0700",
#                         "archGbCdNm": "용도변경",
#                         "archPmsDay": "20000309",
#                         "atchBldDongCnt": "0",
#                         "bcRat": "50.72",
#                         "bjdongCd": "10300",
#                         "bldNm": "12-4",
#                         "block": null,
#                         "bun": "0012",
#                         "crtnDay": "20090320",
#                         "fmlyCnt": "0",
#                         "guyukCd": null,
#                         "guyukCdNm": null,
#                         "hhldCnt": "0",
#                         "hoCnt": "0",
#                         "ji": "0004",
# ...

# %%
import requests
key='T7qWS/9fhkbGnJOLvtsKjAAARGoy/4dtTP7RqVqRuL+cj5jbRt2nEWgA/s3wAsSYW29Kg59YOafhLoqC1KJWLg=='
url = 'http://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo'
params ={'serviceKey' : key, 'sigunguCd' : '11680', 'bjdongCd' : '10300', 'platGbCd' : '0', 'bun' : '0012', 'ji' : '0004', 'startDate' : '20220101', 'endDate' : '20221231', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
contents=response.content
# print(contents)

# %%
jsonString = json.dumps(xmltodict.parse(contents), indent=4, ensure_ascii=False)
print(jsonString)
# Out:
# {
#     "response": {
#         "header": {
#             "resultCode": "00",
#             "resultMsg": "NORMAL SERVICE."
#         },
#         "body": {
#             "items": null,
#             "numOfRows": "10",
#             "pageNo": "1",
#             "totalCount": "0"
#         }
#     }
# }

# %%
key='T7qWS/9fhkbGnJOLvtsKjAAARGoy/4dtTP7RqVqRuL+cj5jbRt2nEWgA/s3wAsSYW29Kg59YOafhLoqC1KJWLg=='

# %%
import requests

url = 'http://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo'
params ={'serviceKey' : key, 'sigunguCd' : '11680', 'bjdongCd' : '10300', 'platGbCd' : '0', 'bun' : '0012', 'ji' : '0004', 'startDate' : '', 'endDate' : '', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><archArea>1152.45</archArea><archGbCd>0700</archGbCd><archGbCdNm>\xec\x9a\xa9\xeb\x8f\x84\xeb\xb3\x80\xea\xb2\xbd</archGbCdNm><archPmsDay>20000309</archPmsDay><atchBldDongCnt>0</atchBldDongCnt><bcRat>50.72</bcRat><bjdongCd>10300</bjdongCd><bldNm>12-4</bldNm><block> </block><bun>0012</bun><crtnDay>20090320</crtnDay><fmlyCnt>0</fmlyCnt><guyukCd> </guyukCd><guyukCdNm> </guyukCdNm><hhldCnt>0</hhldCnt><hoCnt>0</hoCnt><ji>0004</ji><jiguCd> </jiguCd><jiguCdNm> </jiguCdNm><jimokCd>08</jimokCd><jimokCdNm>\xeb\x8c\x80</jimokCdNm><jiyukCd>1020</jiyukCd><jiyukCdNm>\xec\x9d\xbc\xeb\xb0\x98\xec\xa3\xbc\xea\xb1\xb0\xec\xa7\x80\xec\x97\xad</jiyukCdNm><lot> </lot><mainBldCnt>1</mainBldCnt><mainPurpsCd>Z5000</mainPurpsCd><mainPurpsCdNm>\xeb\xac\xb8\xed\x99\x94\xeb\xb0\x8f\xec\xa7\x91\xed\x9a\x8c\xec\x8b\x9c\xec\x84\xa4</mainPurpsCdNm><m
# ...

# %%
contents = response.text

# %%
import pprint
import json

import pprint
pp = pprint.PrettyPrinter(indent=10)
print(pp.pprint(contents))
# Out:
# ('<?xml version="1.0" encoding="UTF-8" '
#  'standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL '
#  'SERVICE.</resultMsg></header><body><items><item><archArea>1152.45</archArea><archGbCd>0700</archGbCd><archGbCdNm>용도변경</archGbCdNm><archPmsDay>20000309</archPmsDay><atchBldDongCnt>0</atchBldDongCnt><bcRat>50.72</bcRat><bjdongCd>10300</bjdongCd><bldNm>12-4</bldNm><block> '
#  '</block><bun>0012</bun><crtnDay>20090320</crtnDay><fmlyCnt>0</fmlyCnt><guyukCd> '
#  '</guyukCd><guyukCdNm> '
#  '</guyukCdNm><hhldCnt>0</hhldCnt><hoCnt>0</hoCnt><ji>0004</ji><jiguCd> '
#  '</jiguCd><jiguCdNm> '
#  '</jiguCdNm><jimokCd>08</jimokCd><jimokCdNm>대</jimokCdNm><jiyukCd>1020</jiyukCd><jiyukCdNm>일반주거지역</jiyukCdNm><lot> '
#  '</lot><mainBldCnt>1</mainBldCnt><mainPurpsCd>Z5000</mainPurpsCd><mainPurpsCdNm>문화및집회시설</mainPurpsCdNm><mgmPmsrgstPk>11680-4402</mgmPmsrgstPk><platArea>2272</platArea><platGbCd>0</platGbCd><platPlc>서울특별시 '
#  '강남구 개포동 12-4번지</platPlc><realStcnsDay> '
# ...

# %%
from urllib.request import urlopen  #1
from bs4 import BeautifulSoup  #2

# date = 202201  #3
# gu_code = 11305  #4
# service_key =  #5

url = f'http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/'\
    f'getRTMSDataSvcAptRent?LAWD_CD={gu_code}&DEAL_YMD={date}&'\
    f'serviceKey={service_key}'  #6

result = urlopen(url)  #7
house = BeautifulSoup(result, 'lxml-xml')  #8
te = house.find_all('item')  #9

# %%
url = 'http://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo'
params ={'serviceKey' : key, 'sigunguCd' : '11680', 'bjdongCd' : '10300', 'platGbCd' : '0', 'bun' : '0012', 'ji' : '0004', 'startDate' : '', 'endDate' : '', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)

# %%
from urllib.request import urlopen  #1
from bs4 import BeautifulSoup  #2
key='T7qWS/9fhkbGnJOLvtsKjAAARGoy/4dtTP7RqVqRuL+cj5jbRt2nEWgA/s3wAsSYW29Kg59YOafhLoqC1KJWLg'
sigunguCd='11010'
bjdongCd="1101053"

url = 'https://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo?serviceKey='+str(key)+'%3D%3D&sigunguCd='+str(sigunguCd)+'&bjdongCd='+str(bjdongCd)+'&platGbCd=0&bun=0012&ji=0004&startDate=20230101&endDate=20230101&numOfRows=10&pageNo=1'

result = urlopen(url)  #7
house = BeautifulSoup(result, 'lxml-xml')  #8
te = house.find_all('item')  #9
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.10/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1282         """Send a complete request to the server."""
# -> 1283         self._send_request(method, url, body, headers, encode_chunked)
#    1284
#
# /usr/lib/python3.10/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1328             body = _encode(body, 'body')
# -> 1329         self.endheaders(body, encode_chunked=encode_chunked)
#    1330
#
# ...

# %%
url = 'https://apis.data.go.kr/1613000/ArchPmsService_v2/getApBasisOulnInfo?serviceKey=T7qWS%2F9fhkbGnJOLvtsKjAAARGoy%2F4dtTP7RqVqRuL%2Bcj5jbRt2nEWgA%2Fs3wAsSYW29Kg59YOafhLoqC1KJWLg%3D%3D&sigunguCd=11010&bjdongCd=1101053&platGbCd=1&bun=0012&ji=0004&startDate=20230101&endDate=20230101&numOfRows=10&pageNo=1'
result = urlopen(url)  #7
house = BeautifulSoup(result, 'lxml-xml')  #8
te = house.find_all('item')  #9
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.10/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1282         """Send a complete request to the server."""
# -> 1283         self._send_request(method, url, body, headers, encode_chunked)
#    1284
#
# /usr/lib/python3.10/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1328             body = _encode(body, 'body')
# -> 1329         self.endheaders(body, encode_chunked=encode_chunked)
#    1330
#
# ...
